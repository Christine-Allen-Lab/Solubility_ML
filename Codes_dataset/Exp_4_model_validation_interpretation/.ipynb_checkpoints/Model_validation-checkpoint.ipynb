# %%
from sklearn.model_selection import cross_val_score, GroupKFold, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_decomposition import PLSRegression
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression, Lasso
import lightgbm as lgb
from skopt.space import Real, Integer, Categorical
from skopt import BayesSearchCV
import shap
import pickle
import matplotlib.image as mpimg
from PIL import Image
import matplotlib.colors as mcolors
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
black = '#515265'
red = '#DD706E'
yellow = '#FAAF3A'
blue = '#3A93C2'

# %%
file_path = "../Exp_2_Dataset_feature_engineering/Summary_and_dataset/refined_dataset.csv"

data = pd.read_csv(file_path)
train = data[data['Type'] == 'Train']
test = data[data['Type'] == 'Test']
lab = data[data['Type'] == 'Lab']

# %%
overlapping_values = set(train['Drug-solvent system']).intersection(test['Drug-solvent system'])
overlapping_values
# Out:
# set()

# %%
def data_processing (dataset):

    X = dataset.drop(['Type', 'Drug', 'Solvent_1', 'Solvent_2', 'Drug-solvent system', 'LogS', 'Class', 'Solubility (g/100g)'], axis = 1)
    Y = dataset['LogS']
    G = dataset['Drug-solvent system']

    return X, Y, G

# %%
X_train, Y_train, G_train = data_processing(train)
X_test, Y_test, G_test = data_processing(test)
X_lab, Y_lab, G_lab = data_processing(lab)

# %% [markdown]
# # Hyperparameter screening

# %%
pickle_file_path = '../Exp_3_model_training_optimization/Original/Results/BSCV_results.pkl'

# %%
with open(pickle_file_path, 'rb') as handle:
    results = pickle.load(handle)
# Out:
# Trying to unpickle estimator DecisionTreeRegressor from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator RandomForestRegressor from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator MLPRegressor from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator LinearRegression from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator Lasso from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator PLSRegression from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# Trying to unpickle estimator KNeighborsRegressor from version 1.1.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations

# %%
results
# Out:
# {'DT': {'best_estimator': DecisionTreeRegressor(max_depth=20, max_features='auto', min_samples_leaf=8,
#                         min_samples_split=0.01, random_state=0,
#                         splitter='random'),
#   'best_params': OrderedDict([('max_depth', 20),
#                ('max_features', 'auto'),
#                ('min_samples_leaf', 8),
#                ('min_samples_split', 0.01),
#                ('splitter', 'random')]),
#   'best_score': -0.4700293292782832},
#  'RF': {'best_estimator': RandomForestRegressor(bootstrap=False, max_depth=18, max_features='sqrt',
#                         min_samples_split=0.01, n_estimators=354, n_jobs=6,
#                         random_state=0),
#   'best_params': OrderedDict([('bootstrap', False),
#                ('max_depth', 18),
#                ('max_features', 'sqrt'),
#                ('min_samples_leaf', 1),
#                ('min_samples_split', 0.01),
#                ('n_estimators', 354)]),
#   'best_score': -0.43535884700904787},
#  'XGB': {'best_estimator': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.5040916758108805, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=0.0018482782618796866, gpu_id=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.06702702670829803, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=8, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=400, n_jobs=6, num_parallel_tree=None, predictor=None,
#                random_state=0, ...),
#   'best_params': OrderedDict([('colsample_bytree', 0.5040916758108805),
#                ('gamma', 0.0018482782618796866),
#                ('learning_rate', 0.06702702670829803),
#                ('max_depth', 8),
#                ('n_estimators', 400),
#                ('subsample', 0.5494224999097781)]),
#   'best_score': -0.3046320069044893},
#  'NN': {'best_estimator': MLPRegressor(alpha=0.08107364178627034, hidden_layer_sizes=64,
#                learning_rate_init=0.013788672221631097, random_state=0),
#   'best_params': OrderedDict([('activation', 'relu'),
#                ('alpha', 0.08107364178627034),
#                ('hidden_layer_sizes', 64),
#                ('learning_rate_init', 0.013788672221631097)]),
#   'best_score': -0.3546500841613265},
#  'LightGBM': {'best_estimator': LGBMRegressor(bagging_fraction=0.5, feature_fraction=0.5,
#                 learning_rate=0.040803979776290245, max_depth=8,
#                 min_child_samples=100, n_estimators=674, n_jobs=6, num_leaves=400,
#                 random_state=0),
#   'best_params': OrderedDict([('bagging_fraction', 0.5),
#                ('feature_fraction', 0.5),
#                ('learning_rate', 0.040803979776290245),
#                ('max_depth', 8),
#                ('min_child_samples', 100),
#                ('n_estimators', 674),
#                ('num_leaves', 400)]),
#   'best_score': -0.30810222432342665},
#  'MLR': {'best_estimator': LinearRegression(fit_intercept=False, positive=True),
#   'best_params': OrderedDict([('fit_intercept', False), ('positive', True)]),
#   'best_score': -1.8330044483378316},
#  'Lasso': {'best_estimator': Lasso(alpha=0.00406296567400916, selection='random'),
#   'best_params': OrderedDict([('alpha', 0.00406296567400916),
#                ('selection', 'random')]),
#   'best_score': -0.4691269289354791},
#  'PLS': {'best_estimator': PLSRegression(max_iter=444, n_components=6),
#   'best_params': OrderedDict([('max_iter', 444), ('n_components', 6)]),
#   'best_score': -0.5055389403105537},
#  'kNN': {'best_estimator': KNeighborsRegressor(algorithm='ball_tree', leaf_size=10, n_jobs=6,
#                       n_neighbors=6, p=1),
#   'best_params': OrderedDict([('algorithm', 'ball_tree'),
#                ('leaf_size', 10),
#                ('n_neighbors', 6),
#                ('p', 1),
#                ('weights', 'uniform')]),
#   'best_score': -0.3728498148103473}}

# %% [markdown]
# # Model evaluation using the literature test set

# %%
best_model = results['XGB']['best_estimator']

# %%
literature_X_scaled = pd.concat([X_train, X_test], ignore_index=True)
literature_Y = pd.concat([Y_train, Y_test], ignore_index=True)

# %%
literature_X_scaled
# Out:
#        Solvent_mass_fraction  Temperature (K)  Drug_Melting_temp (K)  \
# 0                  -1.462508        -1.594466               0.035448
# 1                   0.232488         0.411506               0.311461
# 2                   0.571555         0.077177               0.311461
# 3                   0.571555        -0.257152               0.311461
# 4                   0.571555        -0.591480               0.311461
# ...                      ...              ...                    ...
# 27252               0.575284        -0.925809              -1.030270
# 27253               0.575284         0.745834              -1.030270
# 27254               0.575284         1.080163              -1.030270
# 27255               0.575284         1.414491              -1.030270
# 27256               0.575284         1.748820              -1.030270
#
#        Drug_Maccs_8  Drug_Maccs_15  Drug_Maccs_17  Drug_Maccs_19  \
# 0         -0.098286      -0.090932      -0.067312      -0.257313
# 1         -0.098286      -0.090932      -0.067312      -0.257313
# 2         -0.098286      -0.090932      -0.067312      -0.257313
# 3         -0.098286      -0.090932      -0.067312      -0.257313
# 4         -0.098286      -0.090932      -0.067312      -0.257313
# ...             ...            ...            ...            ...
# 27252     -0.098286      -0.090932      -0.067312       3.886316
# 27253     -0.098286      -0.090932      -0.067312       3.886316
# 27254     -0.098286      -0.090932      -0.067312       3.886316
# 27255     -0.098286      -0.090932      -0.067312       3.886316
# 27256     -0.098286      -0.090932      -0.067312       3.886316
#
#        Drug_Maccs_21  Drug_Maccs_23  Drug_Maccs_24  ...  \
# 0          -0.093197      -0.213749      -0.322175  ...
# 1          -0.093197      -0.213749      -0.322175  ...
# 2          -0.093197      -0.213749      -0.322175  ...
# 3          -0.093197      -0.213749      -0.322175  ...
# 4          -0.093197      -0.213749      -0.322175  ...
# ...              ...            ...            ...  ...
# 27252      -0.093197      -0.213749      -0.322175  ...
# 27253      -0.093197      -0.213749      -0.322175  ...
# 27254      -0.093197      -0.213749      -0.322175  ...
# 27255      -0.093197      -0.213749      -0.322175  ...
# 27256      -0.093197      -0.213749      -0.322175  ...
#
#        Solvent_2_EState_VSA2  Solvent_2_EState_VSA3  Solvent_2_EState_VSA4  \
# 0                  -1.844157               2.395496               1.604105
# 1                   0.629695               2.395496               3.509625
# 2                   0.629695               2.395496               3.509625
# 3                   0.629695               2.395496               3.509625
# 4                   0.629695               2.395496               3.509625
# ...                      ...                    ...                    ...
# 27252               0.425334              -0.244963              -0.301415
# 27253               0.425334              -0.244963              -0.301415
# 27254               0.425334              -0.244963              -0.301415
# 27255               0.425334              -0.244963              -0.301415
# 27256               0.425334              -0.244963              -0.301415
#
#        Solvent_2_EState_VSA5  Solvent_2_EState_VSA6  Solvent_2_EState_VSA9  \
# 0                  -0.381472              -0.545118               0.960140
# 1                   0.672117              -0.545118              -0.612628
# 2                   0.672117              -0.545118              -0.612628
# 3                   0.672117              -0.545118              -0.612628
# 4                   0.672117              -0.545118              -0.612628
# ...                      ...                    ...                    ...
# 27252              -0.381472              -0.545118              -0.612628
# 27253              -0.381472              -0.545118              -0.612628
# 27254              -0.381472              -0.545118              -0.612628
# 27255              -0.381472              -0.545118              -0.612628
# 27256              -0.381472              -0.545118              -0.612628
#
#        Solvent_2_VSA_EState5  Solvent_2_NOCount  \
# 0                  -0.052602           0.078498
# 1                  -2.559062           2.749726
# 2                  -2.559062           2.749726
# 3                  -2.559062           2.749726
# 4                  -2.559062           2.749726
# ...                      ...                ...
# 27252              -0.052602           0.078498
# 27253              -0.052602           0.078498
# 27254              -0.052602           0.078498
# 27255              -0.052602           0.078498
# 27256              -0.052602           0.078498
#
#        Solvent_2_NumAliphaticCarbocycles  Solvent_2_NumAliphaticRings
# 0                              -0.092698                    -0.130403
# 1                              -0.092698                    -0.130403
# 2                              -0.092698                    -0.130403
# 3                              -0.092698                    -0.130403
# 4                              -0.092698                    -0.130403
# ...                                  ...                          ...
# 27252                          -0.092698                    -0.130403
# 27253                          -0.092698                    -0.130403
# 27254                          -0.092698                    -0.130403
# 27255                          -0.092698                    -0.130403
# 27256                          -0.092698                    -0.130403
#
# [27257 rows x 370 columns]

# %%
best_model.fit(literature_X_scaled, literature_Y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5040916758108805, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0018482782618796866, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.06702702670829803, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=400, n_jobs=6, num_parallel_tree=None, predictor=None,
#              random_state=0, ...)

# %%
with open('XGB.pkl', 'wb') as file:
    pickle.dump(best_model, file)

# %%
with open('XGB.pkl', 'rb') as file:
    best_model = pickle.load(file)

# %%
Y_pred = best_model.predict(X_lab)

# %%
summary = pd.DataFrame()

summary['Y_pred'] = Y_pred
summary['Y_exp'] = Y_lab.values
summary['Drug'] = lab['Drug'].values
summary['Temperature'] = lab['Temperature (K)'].values
summary['Solvent_mass_fraction'] = lab['Solvent_mass_fraction'].values
summary
# Out:
#       Y_pred     Y_exp                    Drug  Temperature  \
# 0  -0.427957 -0.732561  3-Indolepropionic acid    -0.257152
# 1   0.939577  1.242254                 Aspirin     0.745834
# 2   0.384925  0.407800                 Aspirin     0.745834
# 3   0.904984  1.297876                 Aspirin    -0.257152
# 4   0.626284  1.001880                 Aspirin    -0.257152
# 5   0.083848  0.051018                 Aspirin    -0.257152
# 6   0.834224  1.313949  3-Indolepropionic acid     0.745834
# 7   0.547817  0.946698  3-Indolepropionic acid     0.745834
# 8  -0.070388 -0.285845  3-Indolepropionic acid     0.745834
# 9   0.548546  1.143119  3-Indolepropionic acid    -0.257152
# 10  0.307486  0.653918  3-Indolepropionic acid    -0.257152
# 11 -0.081347 -3.061188               Celecoxib    -0.257152
# 12  1.484326  1.386752           Acetaminophen     0.745834
# 13  1.285277  1.298532           Acetaminophen     0.745834
# 14  0.529409  0.830016           Acetaminophen     0.745834
# 15  1.174242  1.280612           Acetaminophen    -0.257152
# 16  0.994663  1.165377           Acetaminophen    -0.257152
# 17  0.183861  0.568126           Acetaminophen    -0.257152
# 18  1.088450  0.933291               Celecoxib     0.745834
# 19  0.885107  0.011534               Celecoxib     0.745834
# 20  0.238156 -2.505811               Celecoxib     0.745834
# 21  0.914409  0.685046               Celecoxib    -0.257152
# 22  0.652781 -0.351141               Celecoxib    -0.257152
# 23  1.164928  1.405768                 Aspirin     0.745834
#
#     Solvent_mass_fraction
# 0               -1.123780
# 1               -0.106579
# 2               -1.123780
# 3                0.910622
# 4               -0.106579
# 5               -1.123780
# 6                0.910622
# 7               -0.106579
# 8               -1.123780
# 9                0.910622
# 10              -0.106579
# 11              -1.123780
# 12               0.910622
# 13              -0.106579
# 14              -1.123780
# 15               0.910622
# 16              -0.106579
# 17              -1.123780
# 18               0.910622
# 19              -0.106579
# 20              -1.123780
# 21               0.910622
# 22              -0.106579
# 23               0.910622

# %%
drug_order = ['Celecoxib', 'Acetaminophen', '3-Indolepropionic acid', 'Aspirin']
summary['Drug'] = pd.Categorical(summary['Drug'], categories=drug_order, ordered=True)

summary_sorted = summary.sort_values(by=['Drug', 'Temperature', 'Solvent_mass_fraction'])

summary_sorted = summary_sorted.reset_index(drop = True)
summary_sorted
# Out:
#       Y_pred     Y_exp                    Drug  Temperature  \
# 0  -0.081347 -3.061188               Celecoxib    -0.257152
# 1   0.652781 -0.351141               Celecoxib    -0.257152
# 2   0.914409  0.685046               Celecoxib    -0.257152
# 3   0.238156 -2.505811               Celecoxib     0.745834
# 4   0.885107  0.011534               Celecoxib     0.745834
# 5   1.088450  0.933291               Celecoxib     0.745834
# 6   0.183861  0.568126           Acetaminophen    -0.257152
# 7   0.994663  1.165377           Acetaminophen    -0.257152
# 8   1.174242  1.280612           Acetaminophen    -0.257152
# 9   0.529409  0.830016           Acetaminophen     0.745834
# 10  1.285277  1.298532           Acetaminophen     0.745834
# 11  1.484326  1.386752           Acetaminophen     0.745834
# 12 -0.427957 -0.732561  3-Indolepropionic acid    -0.257152
# 13  0.307486  0.653918  3-Indolepropionic acid    -0.257152
# 14  0.548546  1.143119  3-Indolepropionic acid    -0.257152
# 15 -0.070388 -0.285845  3-Indolepropionic acid     0.745834
# 16  0.547817  0.946698  3-Indolepropionic acid     0.745834
# 17  0.834224  1.313949  3-Indolepropionic acid     0.745834
# 18  0.083848  0.051018                 Aspirin    -0.257152
# 19  0.626284  1.001880                 Aspirin    -0.257152
# 20  0.904984  1.297876                 Aspirin    -0.257152
# 21  0.384925  0.407800                 Aspirin     0.745834
# 22  0.939577  1.242254                 Aspirin     0.745834
# 23  1.164928  1.405768                 Aspirin     0.745834
#
#     Solvent_mass_fraction
# 0               -1.123780
# 1               -0.106579
# 2                0.910622
# 3               -1.123780
# 4               -0.106579
# 5                0.910622
# 6               -1.123780
# 7               -0.106579
# 8                0.910622
# 9               -1.123780
# 10              -0.106579
# 11               0.910622
# 12              -1.123780
# 13              -0.106579
# 14               0.910622
# 15              -1.123780
# 16              -0.106579
# 17               0.910622
# 18              -1.123780
# 19              -0.106579
# 20               0.910622
# 21              -1.123780
# 22              -0.106579
# 23               0.910622

# %%
file_path = "../Exp_1_Raw_Dataset/Raw_dataset_dataset_20240130.csv"
original_data = pd.read_csv(file_path)

lab_X = original_data[original_data['Type'] == 'Lab']
literature_X = original_data[original_data['Type'] != 'Lab']

# %%
cols_of_interest = ['Drug','Drug_ExactMolWt', 'Drug_Melting_temp (K)']

# %%
experiment_STD = [0.026547199, 0.007765518, 0.00609362, 0.011489668, 0.009077589, 0.004943748,
                 0.009819746, 0.007260406, 0.020924193, 0.008093572, 0.005818861, 0.009665102,
                0.016553364, 0.008737235, 0.005338153, 0.021981287, 0.023570222, 0.012345814,
                 0.004954186, 0.007637141, 0.003202658, 0.012285287, 0.0108218, 0.005967770]

# %%
plot = lab_X[['Drug','Solvent_mass_fraction','Temperature (K)','LogS']]
plot['LogS_SD'] = experiment_STD
plot['Y_pred'] = summary_sorted['Y_pred'].values

plot['AE'] = abs(plot['LogS'] - plot['Y_pred'])
plot
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          Drug  Solvent_mass_fraction  Temperature (K)  \
# 27257               Celecoxib                    0.2           298.15
# 27258               Celecoxib                    0.5           298.15
# 27259               Celecoxib                    0.8           298.15
# 27260               Celecoxib                    0.2           313.15
# 27261               Celecoxib                    0.5           313.15
# 27262               Celecoxib                    0.8           313.15
# 27263           Acetaminophen                    0.2           298.15
# 27264           Acetaminophen                    0.5           298.15
# 27265           Acetaminophen                    0.8           298.15
# 27266           Acetaminophen                    0.2           313.15
# 27267           Acetaminophen                    0.5           313.15
# 27268           Acetaminophen                    0.8           313.15
# 27269  3-Indolepropionic acid                    0.2           298.15
# 27270  3-Indolepropionic acid                    0.5           298.15
# 27271  3-Indolepropionic acid                    0.8           298.15
# 27272  3-Indolepropionic acid                    0.2           313.15
# 27273  3-Indolepropionic acid                    0.5           313.15
# 27274  3-Indolepropionic acid                    0.8           313.15
# 27275                 Aspirin                    0.2           298.15
# 27276                 Aspirin                    0.5           298.15
# 27277                 Aspirin                    0.8           298.15
# 27278                 Aspirin                    0.2           313.15
# 27279                 Aspirin                    0.5           313.15
# 27280                 Aspirin                    0.8           313.15
#
#            LogS   LogS_SD    Y_pred        AE
# 27257 -3.061188  0.026547 -0.081347  2.979841
# 27258 -0.351141  0.007766  0.652781  1.003922
# 27259  0.685046  0.006094  0.914409  0.229363
# 27260 -2.505811  0.011490  0.238156  2.743967
# 27261  0.011534  0.009078  0.885107  0.873573
# 27262  0.933291  0.004944  1.088450  0.155159
# 27263  0.568126  0.009820  0.183861  0.384266
# 27264  1.165377  0.007260  0.994663  0.170713
# 27265  1.280612  0.020924  1.174242  0.106370
# 27266  0.830016  0.008094  0.529409  0.300606
# 27267  1.298532  0.005819  1.285277  0.013255
# 27268  1.386752  0.009665  1.484326  0.097574
# 27269 -0.732561  0.016553 -0.427957  0.304604
# 27270  0.653918  0.008737  0.307486  0.346432
# 27271  1.143119  0.005338  0.548546  0.594573
# 27272 -0.285845  0.021981 -0.070388  0.215457
# 27273  0.946698  0.023570  0.547817  0.398880
# 27274  1.313949  0.012346  0.834224  0.479725
# 27275  0.051018  0.004954  0.083848  0.032830
# 27276  1.001880  0.007637  0.626284  0.375595
# 27277  1.297876  0.003203  0.904984  0.392891
# 27278  0.407800  0.012285  0.384925  0.022875
# 27279  1.242254  0.010822  0.939577  0.302677
# 27280  1.405768  0.005968  1.164928  0.240840

# %%
ACM = plot[plot['Drug'] == 'Acetaminophen']

CXB = plot[plot['Drug'] == 'Celecoxib']

IPA = plot[plot['Drug'] == '3-Indolepropionic acid']

ASA = plot[plot['Drug'] == 'Aspirin']

# %%
def exp(df, ax, color, drug, ann):

    unique_temperatures = df['Temperature (K)'].unique()
    fontsize = 12

    width = 0.35  
    x = np.arange(len(df['Solvent_mass_fraction'].unique()))
    
    for i, temp in enumerate(unique_temperatures):
        subset = df[df['Temperature (K)'] == temp]
        
        # Use 'color' for all temperatures
        bar_color = color
        
        # Create bars
        ax.bar(x + i * width, subset['LogS'], width=width, label=f'Temperature {temp} K', color=bar_color, edgecolor='black', linewidth=0.5)
        
        # Overlay patterned bars for 313.15 temperature
        if temp == 313.15:
            ax.bar(x + i * width, subset['LogS'], width=width, hatch='///', edgecolor='black', fill=False, linewidth=0)

    # Add error bars
    for i, temp in enumerate(unique_temperatures):
        subset = df[df['Temperature (K)'] == temp]
        ax.errorbar(x + i * width, subset['LogS'], yerr=subset['LogS_SD'], fmt='none', color='k', capsize=5)

    ax.set_xlabel('Ethanol Fraction')
    ax.set_ylabel('Experimental LogS')
    ax.set_title(drug)  # Add a title if needed
    ax.set_xticks(x + width * (len(unique_temperatures) - 1) / 2)
    ax.set_xticklabels(df['Solvent_mass_fraction'].unique())
    
    # Hide legends
    ax.legend().set_visible(False)
    
    # Draw a line at y=0
    ax.axhline(y=0, color='black', linewidth=0.5)
    
    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
def metrics(df, ax, color, ann):
    # Calculate metrics
    
    fontsize = 12
    mae = mean_absolute_error(df['LogS'], df['Y_pred'])
    medae = median_absolute_error(df['LogS'], df['Y_pred'])
    mse = mean_squared_error(df['LogS'], df['Y_pred'])
    rmse = np.sqrt(mse) 

    # Prepare data for plotting
    metrics = ['MAE', 'MedAE', 'RMSE', 'MSE']
    values = [mae, medae, rmse, mse]

    # Create bar plot on the provided axes
    bars = ax.bar(metrics, values, color = color, edgecolor='black', linewidth=0.5)
    ax.set_xlabel('')
    ax.set_ylabel('Values')
    ax.set_ylim(0, 3.3)
    ax.set_title('')

    # Adding the values on top of the bars
    for bar in bars:
        height = bar.get_height()
        if height >=0:
            ax.text(bar.get_x() + bar.get_width() / 2, height, 
                    f'{height:.2f}', ha='center', va='bottom')
        else:
            ax.text(bar.get_x() + bar.get_width() / 2, 0, 
                    f'{height:.2f}', ha='center', va='bottom')

    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
def scatter(df, ax, color, ann):
    fontsize = 12
    
    # Scatter plot of actual vs predicted LogS values
    ax.scatter(df['LogS'], df['Y_pred'], color=color)

    # Setting the same limits for x and y axis
    max_limit = max(df['LogS'].max(), df['Y_pred'].max())
    min_limit = min(df['LogS'].min(), df['Y_pred'].min())
    ax.set_xlim(min_limit-0.2, max_limit+0.2)
    ax.set_ylim(min_limit-0.2, max_limit+0.2)

    # Setting labels and title
    ax.set_xlabel('Actual LogS')
    ax.set_ylabel('Predicted LogS')
    ax.set_title(df['Drug'].iloc[0])  # Assumes all entries in 'df' are for the same drug

    # Adding annotation
    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
# colors

acm_color = 'dimgray'
ipa_color = red
cxb_color = blue
asa_color = yellow

fig = plt.figure(figsize=(16, 8))
grid = plt.GridSpec(2, 4, wspace=0.3, hspace=0.3)


ax1 = fig.add_subplot(grid[0, 0])
exp(df = ASA, ax = ax1, color = asa_color, ann = 'a)', drug = 'Aspirin')

ax2 = fig.add_subplot(grid[0, 1])
exp(df = ACM, ax = ax2, color = acm_color, ann = 'b)', drug = 'Acetaminophen')


ax3 = fig.add_subplot(grid[0,2])
exp(df = IPA, ax = ax3, color = ipa_color, ann = 'c)', drug = '3-Indolepropionic acid')


ax4 = fig.add_subplot(grid[0, 3])
exp(df = CXB, ax = ax4, color = cxb_color, ann = 'd)', drug = 'Celecoxib')



ax5 = fig.add_subplot(grid[1, 0])
metrics(df = ASA, ax = ax5, color = asa_color, ann = 'e)')

ax6 = fig.add_subplot(grid[1, 1])
metrics(df = ACM, ax = ax6, color = acm_color, ann = 'f)')


ax7 = fig.add_subplot(grid[1,2])
metrics(df = IPA, ax = ax7, color = ipa_color, ann = 'g)')


ax8 = fig.add_subplot(grid[1, 3])
metrics(df = CXB, ax = ax8, color = cxb_color, ann = 'h)')






fig.patch.set(facecolor='none')

plt.tight_layout()

fig.canvas.print_figure('Figure_5_Model_Validation.png', dpi=600)


plt.show()
# Out:
# This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5040916758108805, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0018482782618796866, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.06702702670829803, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=400, n_jobs=6, num_parallel_tree=None, predictor=None,
#              random_state=0, ...)

# %%
def plot_feature_importance_xgb(booster, ax, selected, ann, importance_type='weight', top_n=15, filter_drug_features=True):
    fontsize = 12
    
    # Accessing feature importances
    importances = booster.get_score(importance_type=importance_type)
    feature_names = list(importances.keys())
    importance_values = list(importances.values())

    # Creating DataFrame for feature importances
    importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance_values})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    # Filter for drug features if required
    if filter_drug_features:
        importance_df = importance_df[importance_df['Feature'].str.startswith('Drug_')]

    # Selecting top n features for plotting
    importance_df_top_n = importance_df.head(top_n)

    # Plotting
    palette_choice = ['lightcoral' if feature in selected else blue for feature in importance_df_top_n['Feature']]
    bars = sns.barplot(x='Importance', y='Feature', data=importance_df_top_n, ax=ax, palette=palette_choice, edgecolor='black')
    
    # Annotation and title settings
    ax.annotate(ann, xy=(0, 1.025), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)
    ax.set_title("", fontsize=fontsize)
    
    # Setting x/y axis titles and adjusting their font sizes
    ax.set_xlabel("Feature Importance", fontsize=fontsize)
    ax.set_ylabel("", fontsize=fontsize)

    # Adjust the ticks' font size
    ax.tick_params(axis='x', which='major', labelsize=fontsize)
    ax.tick_params(axis='x', which='minor', labelsize=fontsize)
    ax.tick_params(axis='y', which='major', labelsize=fontsize)
    ax.tick_params(axis='y', which='minor', labelsize=fontsize)
    
    return importance_df_top_n

# %%
lab_X['Type'] = lab_X['Drug']
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def plot_distribution_with_labels_on_trend(ann, prop, ax, show_legend=False, legend_pos = (-0.08, 1.28), ncol = 2):
    fontsize = 12
    
    # Assuming literature_X is a DataFrame you have defined elsewhere
    sns.boxplot(y=literature_X[prop], color='lightcoral', fliersize=1, ax=ax)
    
    #Simplifying for four drugs
    unique_drugs = ['Aspirin','Acetaminophen', '3-Indolepropionic acid', 'Celecoxib']
    colors = [yellow, black, red, blue]
    
    drug_color_map = dict(zip(unique_drugs, colors))
    
    x_positions = np.linspace(-0.0, 0.0, len(unique_drugs))
    
    # For legend
    legend_handles = []
    
    
    for idx, drug in enumerate(unique_drugs):
        drug_data = lab_X[lab_X["Drug"] == drug]  # Assuming lab_X is a DataFrame
        scatter = ax.scatter([x_positions[idx]] * len(drug_data), drug_data[prop], 
                             color=drug_color_map[drug], label=drug, 
                             alpha=1.0, edgecolor='black', linewidth=0.8, s=180,
                             zorder=10)  # Ensure scatter is on top with high zorder
        legend_handles.append(scatter)
    
    ax.set_ylabel('', fontsize=fontsize)
    ax.set_title(prop, fontsize=fontsize)
    
    # Adjust the ticks' font size
    ax.tick_params(axis='both', which='major', labelsize=fontsize)
    ax.tick_params(axis='both', which='minor', labelsize=fontsize)
    
    if show_legend:
        ax.legend(handles=legend_handles, title='', loc='upper left', bbox_to_anchor=legend_pos, frameon=False, ncol=ncol, fontsize=fontsize+1)
        
    ax.annotate(ann, xy=(0, 1.05), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
fig = plt.figure(figsize=(18, 12))
grid = gridspec.GridSpec(2, 4, fig, wspace=0.2, hspace=0.1)
selected=['Drug_MinPartialCharge', 'Drug_MinEStateIndex', 'Drug_MaxEStateIndex', 'Drug_MaxPartialCharge']


ax1 = fig.add_subplot(grid[0:2, 0:2])
important_features = plot_feature_importance_xgb(booster=best_model.get_booster(), ax=ax1,  selected=selected, ann = 'a)')

ax2 = fig.add_subplot(grid[0, 2])
plot_distribution_with_labels_on_trend(ann = 'b)',prop='Drug_MinPartialCharge', ax=ax2, legend_pos = (0.25, 1.25), ncol = 2, show_legend=True)


ax3 = fig.add_subplot(grid[0, 3])
plot_distribution_with_labels_on_trend(ann = 'c)',prop='Drug_MinEStateIndex', ax=ax3, show_legend=False)



ax4 = fig.add_subplot(grid[1, 2])
plot_distribution_with_labels_on_trend(ann = 'd)',prop='Drug_MaxEStateIndex', ax=ax4, show_legend=False)



ax5 = fig.add_subplot(grid[1, 3])
plot_distribution_with_labels_on_trend(ann = 'e)',prop='Drug_MaxPartialCharge', ax=ax5, show_legend=False)


fig.patch.set(facecolor='none')



fig.canvas.print_figure('Figure_6_Model_Interpretation.png', dpi=600)


plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(22, 12))

all_important_features = plot_feature_importance_xgb(booster=best_model.get_booster(), ax=ax1, selected='', ann='', top_n=20, filter_drug_features=False)

fig.patch.set(facecolor='none')
fig.savefig('Figure_SI_top 20 features.png', dpi=600)

plt.show()

# %%
important_features
# Out:
#                     Feature  Importance
# 2     Drug_Melting_temp (K)      1907.0
# 114                Drug_qed       351.0
# 118   Drug_FpDensityMorgan1       310.0
# 113  Drug_MinAbsEStateIndex       290.0
# 116   Drug_MaxPartialCharge       282.0
# 117   Drug_MinPartialCharge       272.0
# 112     Drug_MinEStateIndex       271.0
# 120       Drug_BCUT2D_MWLOW       268.0
# 127      Drug_HallKierAlpha       253.0
# 111     Drug_MaxEStateIndex       252.0
# 115              Drug_MolWt       250.0
# 119   Drug_FpDensityMorgan3       249.0
# 124        Drug_BCUT2D_MRHI       230.0
# 121       Drug_BCUT2D_CHGHI       226.0
# 140          Drug_PEOE_VSA7       207.0

# %%
# Create the figure with GridSpec layout
fig = plt.figure(figsize=(25, 15))  
gs = gridspec.GridSpec(3, 5, fig) 

# Loop through the 15 important features
for i, feature in enumerate(important_features['Feature']):
    row = i // 5  # Integer division to determine row
    col = i % 5   # Remainder to determine column
    ax = fig.add_subplot(gs[row, col])

    # Call the plotting function for each feature
    plot_distribution_with_labels_on_trend(
        ann=f'({chr(97+i)})',  # Generates subplot annotations from a to o
        prop=feature,
        ax=ax,
        show_legend=(i==14), legend_pos = (-3, 3.65), ncol = 4  # Optionally, show legend only in the last plot for clarity
    )

plt.tight_layout()


fig.patch.set(facecolor='none')
fig.canvas.print_figure('Figure_SI_All_feture_distribution.png', dpi=600)

plt.show()
# Out:
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %%
def print_summary_with_deviation_count():
    # Calculate the Q1 and Q3 for each feature in literature_X
    quantiles = literature_X.quantile([0.25, 0.75])
    
    # For each drug, check if it deviates from the distribution of each feature
    unique_drugs = ['Acetaminophen', '3-Indolepropionic acid', 'Celecoxib', 'Aspirin']
    summary = []
    
    for feature in important_features['Feature']:
        Q1, Q3 = quantiles[feature].values
        for drug in unique_drugs:
            drug_data = lab_X[lab_X["Drug"] == drug]
            drug_feature_values = drug_data[feature]
            
            # Check for deviations
            below_Q1 = drug_feature_values < Q1
            above_Q3 = drug_feature_values > Q3
            
            deviation = "deviates" if any(below_Q1) or any(above_Q3) else "does not deviate"
            
            summary.append([drug, feature, deviation])
    
    # Convert summary to DataFrame for better organization and readability
    summary_df = pd.DataFrame(summary, columns=['Drug', 'Feature', 'Deviation'])
    summary_pivot = summary_df.pivot(index='Drug', columns='Feature', values='Deviation')
    
    # Count the number of "deviates" for each drug
    deviation_counts = summary_df.groupby('Drug')['Deviation'].apply(lambda x: (x == "deviates").sum()).reset_index(name='Deviation Count')
    
    # Merge the count with the pivoted DataFrame
    summary_with_counts = summary_pivot.merge(deviation_counts, left_on='Drug', right_on='Drug')
    summary_with_counts.set_index('Drug', inplace=True)
    
    # Reorder the columns to put "Deviation Count" at the beginning
    columns_order = ['Deviation Count'] + [col for col in summary_with_counts if col != 'Deviation Count']
    summary_with_counts = summary_with_counts[columns_order]
    
    return summary_with_counts

# Call the function and display the DataFrame with deviation counts
summary_with_counts = print_summary_with_deviation_count()

# %%
summary_with_counts
# Out:
#                         Deviation Count Drug_BCUT2D_CHGHI  Drug_BCUT2D_MRHI  \
# Drug
# 3-Indolepropionic acid                4          deviates  does not deviate
# Acetaminophen                         3          deviates  does not deviate
# Aspirin                               2  does not deviate  does not deviate
# Celecoxib                            11          deviates          deviates
#
#                        Drug_BCUT2D_MWLOW Drug_FpDensityMorgan1  \
# Drug
# 3-Indolepropionic acid  does not deviate      does not deviate
# Acetaminophen           does not deviate      does not deviate
# Aspirin                 does not deviate      does not deviate
# Celecoxib               does not deviate      does not deviate
#
#                        Drug_FpDensityMorgan3 Drug_HallKierAlpha  \
# Drug
# 3-Indolepropionic acid              deviates   does not deviate
# Acetaminophen               does not deviate   does not deviate
# Aspirin                     does not deviate   does not deviate
# Celecoxib                           deviates           deviates
#
#                        Drug_MaxEStateIndex Drug_MaxPartialCharge  \
# Drug
# 3-Indolepropionic acid    does not deviate      does not deviate
# Acetaminophen             does not deviate      does not deviate
# Aspirin                   does not deviate              deviates
# Celecoxib                         deviates              deviates
#
#                        Drug_Melting_temp (K) Drug_MinAbsEStateIndex  \
# Drug
# 3-Indolepropionic acid      does not deviate       does not deviate
# Acetaminophen               does not deviate       does not deviate
# Aspirin                     does not deviate               deviates
# Celecoxib                   does not deviate       does not deviate
#
#                        Drug_MinEStateIndex Drug_MinPartialCharge  \
# Drug
# 3-Indolepropionic acid    does not deviate              deviates
# Acetaminophen             does not deviate              deviates
# Aspirin                   does not deviate      does not deviate
# Celecoxib                         deviates              deviates
#
#                               Drug_MolWt    Drug_PEOE_VSA7          Drug_qed
# Drug
# 3-Indolepropionic acid  does not deviate  does not deviate          deviates
# Acetaminophen                   deviates  does not deviate  does not deviate
# Aspirin                 does not deviate  does not deviate  does not deviate
# Celecoxib                       deviates          deviates          deviates
