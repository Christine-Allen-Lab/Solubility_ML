# %%
from sklearn.model_selection import cross_val_score, GroupKFold, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
from scipy.stats import pearsonr, spearmanr
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_decomposition import PLSRegression
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression, Lasso
import lightgbm as lgb
from skopt.space import Real, Integer, Categorical
from skopt import BayesSearchCV
import shap
import pickle
import matplotlib.image as mpimg
from PIL import Image
import matplotlib.colors as mcolors
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import gridspec


from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from scipy.spatial.distance import mahalanobis
from scipy.linalg import inv
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Data for

# %%
#data_for = '_ExpMP'

#data_for = '_PredMP'
data_for = '_NoMP'

# %%
black = '#515265'
red = '#DD706E'
yellow = '#FAAF3A'
blue = '#3A93C2'

# %%
file_path = "../Exp_2_Dataset_feature_engineering/Summary_and_dataset/refined_dataset" + data_for + ".csv"

data = pd.read_csv(file_path)
train = data[data['Type'] == 'Train']
test = data[data['Type'] == 'Test']
lab = data[data['Type'] == 'Lab']

# %%
overlapping_values = set(train['Drug-solvent system']).intersection(test['Drug-solvent system'])
overlapping_values
# Out:
# set()

# %%
def data_processing (dataset):

    X = dataset.drop(['Type', 'Drug', 'Solvent_1', 'Solvent_2', 'Drug-solvent system', 'LogS', 'Class', 'Solubility (g/100g)'], axis = 1)
    Y = dataset['LogS']
    G = dataset['Drug-solvent system']

    return X, Y, G

# %%
X_train, Y_train, G_train = data_processing(train)
X_test, Y_test, G_test = data_processing(test)
X_lab, Y_lab, G_lab = data_processing(lab)

# %% [markdown]
# # Hyperparameter screening

# %%
pickle_file_path = '../Exp_3_model_training_optimization/Original/Results/BSCV_results' + data_for + '.pkl'

# %%
with open(pickle_file_path, 'rb') as handle:
    results = pickle.load(handle)

# %%
results
# Out:
# {'LightGBM': {'best_estimator': LGBMRegressor(bagging_fraction=0.5, feature_fraction=0.5,
#                 learning_rate=0.05087555013835313, max_depth=11,
#                 min_child_samples=100, n_estimators=1000, n_jobs=6, num_leaves=36,
#                 random_state=0),
#   'best_params': OrderedDict([('bagging_fraction', 0.5),
#                ('feature_fraction', 0.5),
#                ('learning_rate', 0.05087555013835313),
#                ('max_depth', 11),
#                ('min_child_samples', 100),
#                ('n_estimators', 1000),
#                ('num_leaves', 36)]),
#   'best_score': -0.2982927809371689,
#   'optimization_history': {'mean_fit_time': array([ 56.04551094,  27.3409677 ,  20.22257323,  39.6937469 ,
#             9.46178484,  25.5800818 ,  27.09327905,   4.55971847,
#            66.13788357, 171.78836439,  38.40069172,  31.99701416,
#            32.54690781,  17.2047832 ,  16.71059821,  41.23009405,
#            23.25816438,  13.55366316,  17.45292826,   3.64135649,
#            16.66558604, 108.98739481,  22.21569536,  16.91874394,
#            16.58024795,  16.03035836,   3.0271765 ,  86.3285012 ,
#           283.88931313,  14.44050188,  22.62811172,  13.02810218,
#            26.89014845,  48.49386501, 145.24642756,   8.56421907,
#           124.05603788,  11.03779738,   3.43378849,  12.55410979,
#           109.34260843,  92.22515633,  18.54146652,  27.9160516 ,
#           365.54697115,  27.20769513,  26.70141308,  18.42394998,
#            21.5059633 ,   9.95217526,  91.41339869,  97.83657939,
#           119.7091258 ,  25.1692996 ,  24.10899301,  21.11269019,
#            60.92924352,  20.20290835,  25.03775785,  28.97953844,

#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_max_depth': masked_array(data=[14, 13, 6, 11, 8, 11, 6, 3, 19, 17, 8, 6, 6, 3, 5, 6,
#                       11, 3, 20, 19, 12, 20, 3, 20, 3, 20, 3, 14, 20, 18, 3,
#                       3, 20, 11, 13, 3, 20, 20, 20, 3, 20, 20, 7, 20, 20, 16,
#                       8, 9, 6, 20, 20, 20, 20, 12, 20, 3, 15, 3, 11, 9, 7,
#                       10, 20, 20, 14, 10, 6, 7, 17, 20, 16, 8, 9, 20, 17, 20,
#                       6, 20, 7, 6, 10, 9, 15, 8, 13, 8, 3, 10, 14, 20, 9, 16,
#                       20, 9, 11, 7, 20, 10, 12, 11],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_min_child_samples': masked_array(data=[87, 30, 28, 83, 22, 37, 28, 10, 48, 12, 69, 68, 79, 96,
#                       58, 29, 33, 100, 5, 100, 5, 100, 41, 100, 5, 100, 100,
#                       21, 5, 100, 5, 100, 100, 100, 13, 35, 100, 100, 100,
#                       100, 100, 92, 28, 5, 5, 100, 74, 5, 100, 47, 100, 5,
#                       100, 100, 24, 100, 92, 100, 100, 100, 100, 100, 100,
#                       100, 62, 100, 100, 22, 100, 100, 88, 100, 70, 100, 31,
#                       100, 50, 100, 100, 64, 14, 5, 100, 100, 100, 5, 10,
#                       100, 100, 100, 100, 100, 100, 100, 100, 100, 73, 100,
#                       5, 100],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_n_estimators': masked_array(data=[983, 247, 408, 711, 328, 352, 871, 316, 588, 769, 1000,
#                       1000, 1000, 760, 1000, 1000, 100, 569, 1000, 100, 599,
#                       1000, 1000, 1000, 718, 1000, 100, 602, 1000, 727, 1000,
#                       565, 1000, 1000, 1000, 695, 1000, 387, 100, 543, 1000,
#                       1000, 651, 1000, 1000, 1000, 945, 1000, 1000, 345, 864,
#                       447, 1000, 885, 912, 1000, 568, 1000, 1000, 468, 1000,
#                       891, 867, 1000, 339, 1000, 475, 200, 605, 100, 1000,
#                       487, 1000, 721, 1000, 573, 1000, 301, 1000, 100, 622,
#                       314, 1000, 1000, 737, 1000, 100, 393, 1000, 612, 828,
#                       1000, 1000, 1000, 1000, 1000, 970, 1000, 1000, 719],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'param_num_leaves': masked_array(data=[60, 311, 260, 340, 16, 341, 185, 62, 155, 296, 385, 17,
#                       235, 189, 10, 146, 400, 10, 10, 10, 10, 400, 400, 10,
#                       10, 10, 10, 204, 400, 10, 10, 10, 10, 36, 186, 10, 400,
#                       10, 10, 302, 400, 80, 10, 10, 400, 10, 10, 10, 18, 10,
#                       169, 187, 400, 10, 10, 400, 285, 400, 10, 213, 162,
#                       170, 211, 159, 400, 99, 318, 356, 400, 400, 10, 400,
#                       10, 10, 233, 400, 10, 400, 122, 10, 10, 400, 305, 120,
#                       198, 10, 400, 318, 400, 210, 236, 10, 268, 303, 400,
#                       179, 12, 400, 400, 400],
#                 mask=[False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False, False, False, False, False,
#                       False, False, False, False],
#           fill_value='?',
#                dtype=object),
#    'params': [OrderedDict([('bagging_fraction', 0.7654820824760737),
#                  ('feature_fraction', 0.8380397544384568),
#                  ('learning_rate', 0.08314149149079444),
#                  ('max_depth', 14),
#                  ('min_child_samples', 87),
#                  ('n_estimators', 983),
#                  ('num_leaves', 60)]),
#     OrderedDict([('bagging_fraction', 0.629185830986374),
#                  ('feature_fraction', 0.9894518292131809),
#                  ('learning_rate', 0.21972204394324293),
#                  ('max_depth', 13),
#                  ('min_child_samples', 30),
#                  ('n_estimators', 247),
#                  ('num_leaves', 311)]),
#     OrderedDict([('bagging_fraction', 0.7643458710377254),
#                  ('feature_fraction', 0.5289489218467651),
#                  ('learning_rate', 0.032032745103304144),
#                  ('max_depth', 6),
#                  ('min_child_samples', 28),
#                  ('n_estimators', 408),
#                  ('num_leaves', 260)]),
#     OrderedDict([('bagging_fraction', 0.5737099059755859),
#                  ('feature_fraction', 0.8916331353364969),
#                  ('learning_rate', 0.049449776216282514),
#                  ('max_depth', 11),
#                  ('min_child_samples', 83),
#                  ('n_estimators', 711),
#                  ('num_leaves', 340)]),
#     OrderedDict([('bagging_fraction', 0.6162570141151325),
#                  ('feature_fraction', 0.6216679677341995),
#                  ('learning_rate', 0.1190177982450834),
#                  ('max_depth', 8),
#                  ('min_child_samples', 22),
#                  ('n_estimators', 328),
#                  ('num_leaves', 16)]),
#     OrderedDict([('bagging_fraction', 0.9190831912766004),
#                  ('feature_fraction', 0.9956120269464492),
#                  ('learning_rate', 0.12115201170479983),
#                  ('max_depth', 11),
#                  ('min_child_samples', 37),
#                  ('n_estimators', 352),
#                  ('num_leaves', 341)]),
#     OrderedDict([('bagging_fraction', 0.9835656124421499),
#                  ('feature_fraction', 0.8782764530210248),
#                  ('learning_rate', 0.04271271661426047),
#                  ('max_depth', 6),
#                  ('min_child_samples', 28),
#                  ('n_estimators', 871),
#                  ('num_leaves', 185)]),
#     OrderedDict([('bagging_fraction', 0.7552445232092422),
#                  ('feature_fraction', 0.7634895156575092),
#                  ('learning_rate', 0.11645353510171558),
#                  ('max_depth', 3),
#                  ('min_child_samples', 10),
#                  ('n_estimators', 316),
#                  ('num_leaves', 62)]),
#     OrderedDict([('bagging_fraction', 0.546027248452608),
#                  ('feature_fraction', 0.9480863089293394),
#                  ('learning_rate', 0.1486172413028015),
#                  ('max_depth', 19),
#                  ('min_child_samples', 48),
#                  ('n_estimators', 588),
#                  ('num_leaves', 155)]),
#     OrderedDict([('bagging_fraction', 0.6847684887002612),
#                  ('feature_fraction', 0.7200918168694508),
#                  ('learning_rate', 0.024356781908842783),
#                  ('max_depth', 17),
#                  ('min_child_samples', 12),
#                  ('n_estimators', 769),
#                  ('num_leaves', 296)]),
#     OrderedDict([('bagging_fraction', 0.6556450355488075),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.16782022944921562),
#                  ('max_depth', 8),
#                  ('min_child_samples', 69),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 385)]),
#     OrderedDict([('bagging_fraction', 0.9001281358255575),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03102819980117987),
#                  ('max_depth', 6),
#                  ('min_child_samples', 68),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 17)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5925106627832393),
#                  ('learning_rate', 0.1932253605652122),
#                  ('max_depth', 6),
#                  ('min_child_samples', 79),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 235)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.19931622278455813),
#                  ('max_depth', 3),
#                  ('min_child_samples', 96),
#                  ('n_estimators', 760),
#                  ('num_leaves', 189)]),
#     OrderedDict([('bagging_fraction', 0.9770227278776553),
#                  ('feature_fraction', 0.8444968913318831),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 5),
#                  ('min_child_samples', 58),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5389789583642505),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.058586631162067256),
#                  ('max_depth', 6),
#                  ('min_child_samples', 29),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 146)]),
#     OrderedDict([('bagging_fraction', 0.6754284835875676),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 11),
#                  ('min_child_samples', 33),
#                  ('n_estimators', 100),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 569),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.903876202902037),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05362012557792688),
#                  ('max_depth', 19),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 100),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05241472129488777),
#                  ('max_depth', 12),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 599),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.033513285836804664),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.046115434770884096),
#                  ('max_depth', 3),
#                  ('min_child_samples', 41),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.025886782473844017),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.06574434572249058),
#                  ('max_depth', 3),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 718),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.08634419284972591),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 100),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.9873979487245449),
#                  ('feature_fraction', 0.9418407456545344),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 14),
#                  ('min_child_samples', 21),
#                  ('n_estimators', 602),
#                  ('num_leaves', 204)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.07986467729157636),
#                  ('max_depth', 20),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.6221747852020645),
#                  ('learning_rate', 0.03455349668610484),
#                  ('max_depth', 18),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 727),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.14239259782941832),
#                  ('max_depth', 3),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05709469866585701),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 565),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05087555013835313),
#                  ('max_depth', 11),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 36)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.034059193753378035),
#                  ('max_depth', 13),
#                  ('min_child_samples', 13),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 186)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.9825415889760609),
#                  ('learning_rate', 0.02977439302018242),
#                  ('max_depth', 3),
#                  ('min_child_samples', 35),
#                  ('n_estimators', 695),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.09536435219188137),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 387),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 100),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04640246695768725),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 543),
#                  ('num_leaves', 302)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.02371594643511826),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.8091951151934377),
#                  ('feature_fraction', 0.5372888852854593),
#                  ('learning_rate', 0.024617238561263282),
#                  ('max_depth', 20),
#                  ('min_child_samples', 92),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 80)]),
#     OrderedDict([('bagging_fraction', 0.8041998596126928),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04916327616694327),
#                  ('max_depth', 7),
#                  ('min_child_samples', 28),
#                  ('n_estimators', 651),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.02960541273322198),
#                  ('max_depth', 20),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.020714502330560203),
#                  ('max_depth', 20),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5620180913492135),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03913509544589196),
#                  ('max_depth', 16),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5084755032341048),
#                  ('learning_rate', 0.04201012656120355),
#                  ('max_depth', 8),
#                  ('min_child_samples', 74),
#                  ('n_estimators', 945),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.8441868452122111),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.018796103496527262),
#                  ('max_depth', 9),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.9285069600114861),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.048631574962785244),
#                  ('max_depth', 6),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 18)]),
#     OrderedDict([('bagging_fraction', 0.8348144267666062),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 47),
#                  ('n_estimators', 345),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.056690729286900624),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 864),
#                  ('num_leaves', 169)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04740913661014145),
#                  ('max_depth', 20),
#                  ('min_child_samples', 5),
#                  ('n_estimators', 447),
#                  ('num_leaves', 187)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.06283768469092745),
#                  ('max_depth', 12),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 885),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.7291410002129134),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05207753686737563),
#                  ('max_depth', 20),
#                  ('min_child_samples', 24),
#                  ('n_estimators', 912),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.649646890677762),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03627814234451076),
#                  ('max_depth', 15),
#                  ('min_child_samples', 92),
#                  ('n_estimators', 568),
#                  ('num_leaves', 285)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 3),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.8265824074869537),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.16785724041521985),
#                  ('max_depth', 11),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.6705340475675381),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04332154551235526),
#                  ('max_depth', 9),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 468),
#                  ('num_leaves', 213)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.034985873311680626),
#                  ('max_depth', 7),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 162)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.06411125897722444),
#                  ('max_depth', 10),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 891),
#                  ('num_leaves', 170)]),
#     OrderedDict([('bagging_fraction', 0.9525639262299048),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03264178444019072),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 867),
#                  ('num_leaves', 211)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.01),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 159)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04527656327860866),
#                  ('max_depth', 14),
#                  ('min_child_samples', 62),
#                  ('n_estimators', 339),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 1.0),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.0442150639286139),
#                  ('max_depth', 10),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 99)]),
#     OrderedDict([('bagging_fraction', 0.7317832870695344),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.2260493589125875),
#                  ('max_depth', 6),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 475),
#                  ('num_leaves', 318)]),
#     OrderedDict([('bagging_fraction', 0.5002450180829076),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05103607537692081),
#                  ('max_depth', 7),
#                  ('min_child_samples', 22),
#                  ('n_estimators', 200),
#                  ('num_leaves', 356)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.04627007509871465),
#                  ('max_depth', 17),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 605),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 100),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.07261187841438771),
#                  ('max_depth', 16),
#                  ('min_child_samples', 88),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03680871536804098),
#                  ('max_depth', 8),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 487),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.08574836940334911),
#                  ('max_depth', 9),
#                  ('min_child_samples', 70),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.08585507823551984),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 721),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03441320234968116),
#                  ('max_depth', 17),
#                  ('min_child_samples', 31),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 233)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.03458986275771033),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 573),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.616861760116237),
#                  ('feature_fraction', 1.0),
#                  ('learning_rate', 0.29999999999999993),
#                  ('max_depth', 6),
#                  ('min_child_samples', 50),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.9452266403614915),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.08085720518394224),
#                  ('max_depth', 20),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 301),
#                  ('num_leaves', 400)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.041060719526565835),
#                  ('max_depth', 7),
#                  ('min_child_samples', 100),
#                  ('n_estimators', 1000),
#                  ('num_leaves', 122)]),
#     OrderedDict([('bagging_fraction', 0.5251637999046341),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.05548825597357854),
#                  ('max_depth', 6),
#                  ('min_child_samples', 64),
#                  ('n_estimators', 100),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.6288692205637678),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.13434406727537032),
#                  ('max_depth', 10),
#                  ('min_child_samples', 14),
#                  ('n_estimators', 622),
#                  ('num_leaves', 10)]),
#     OrderedDict([('bagging_fraction', 0.5),
#                  ('feature_fraction', 0.5),
#                  ('learning_rate', 0.08727182429496004),
#                  ('max_depth', 9),
#                  ('min_child_samples', 5),
# ...
#           -0.44229142, -0.47545894, -0.43563471, -0.46345597, -0.44359876,
#           -0.47639059, -0.44206605, -0.43271325, -0.4188787 , -0.51360267,
#           -0.47356799, -0.44059541, -0.39260985, -0.39307547, -0.44806386]),
#    'split2_test_score': array([-0.31132129, -0.34213688, -0.33295171, -0.31038546, -0.32344084,
#           -0.33056812, -0.30893221, -0.45148013, -0.33379794, -0.4908371 ,
#           -0.33668124, -0.42120873, -0.34136074, -0.32303517, -0.35547142,
#           -0.29841737, -0.43816762, -0.31289691, -0.29862587, -0.33108684,
#           -0.68226055, -0.3155449 , -0.29505829, -0.32031777, -0.32030429,
#           -0.41437376, -0.31223994, -0.34039345, -0.33217749, -0.38613052,
#            16,  30,  15,  44, 100,  56,  37,  26,  24,  12,  13,  62,  34,
#             3,  11,   5,  20,   9,  72,  39,   2,  23,   4,  40,  57,  31,
#             7,  14,   8,  42,  27,   6,   1,  22,  52], dtype=int32)}}}

# %% [markdown]
# # Model evaluation using the literature test set

# %%
## Check again

best_model = results['XGB']['best_estimator']

# %%
best_model = lgb.LGBMRegressor()

#best_model = XGBRegressor()

# %%
literature_X_scaled = pd.concat([X_train, X_test], ignore_index=True)
literature_Y = pd.concat([Y_train, Y_test], ignore_index=True)

# %%
literature_X_scaled
# Out:
#        Solvent_mass_fraction  Temperature (K)  Drug_Maccs_8  Drug_Maccs_15  \
# 0                   1.356555        -0.581841     -0.103283      -0.095549
# 1                  -1.084714         1.083114     -0.103283      -0.095549
# 2                   1.608907         1.083114     -0.103283      -0.095549
# 3                   1.272204         1.083114     -0.103283      -0.095549
# 4                   0.935502         1.083114     -0.103283      -0.095549
# ...                      ...              ...           ...            ...
# 26701               0.262097         0.084141     -0.103283      -0.095549
# 26702               0.598799         0.084141     -0.103283      -0.095549
# 26703               0.935502         0.084141     -0.103283      -0.095549
# 26704              -0.411309         0.084141     -0.103283      -0.095549
# 26705               1.272204         0.084141     -0.103283      -0.095549
#
#        Drug_Maccs_17  Drug_Maccs_19  Drug_Maccs_23  Drug_Maccs_24  \
# 0          -0.070716      -0.231134      -0.202672       2.924313
# 1          -0.070716      -0.231134      -0.202672       2.924313
# 2          -0.070716      -0.231134      -0.202672       2.924313
# 3          -0.070716      -0.231134      -0.202672       2.924313
# 4          -0.070716      -0.231134      -0.202672       2.924313
# ...              ...            ...            ...            ...
# 26701      -0.070716      -0.231134      -0.202672      -0.341961
# 26702      -0.070716      -0.231134      -0.202672      -0.341961
# 26703      -0.070716      -0.231134      -0.202672      -0.341961
# 26704      -0.070716      -0.231134      -0.202672      -0.341961
# 26705      -0.070716      -0.231134      -0.202672      -0.341961
#
#        Drug_Maccs_25  Drug_Maccs_26  ...  Solvent_2_TPSA  \
# 0           -0.22516       -0.10862  ...       -0.850103
# 1           -0.22516       -0.10862  ...        0.742828
# 2           -0.22516       -0.10862  ...        0.742828
# 3           -0.22516       -0.10862  ...        0.742828
# 4           -0.22516       -0.10862  ...        0.742828
# ...              ...            ...  ...             ...
# 26701       -0.22516       -0.10862  ...       -0.501270
# 26702       -0.22516       -0.10862  ...       -0.501270
# 26703       -0.22516       -0.10862  ...       -0.501270
# 26704       -0.22516       -0.10862  ...       -0.501270
# 26705       -0.22516       -0.10862  ...       -0.501270
#
#        Solvent_2_EState_VSA2  Solvent_2_EState_VSA3  Solvent_2_EState_VSA4  \
# 0                   0.563463               1.860413               1.641052
# 1                   0.439870              -0.272608              -0.341898
# 2                   0.439870              -0.272608              -0.341898
# 3                   0.439870              -0.272608              -0.341898
# 4                   0.439870              -0.272608              -0.341898
# ...                      ...                    ...                    ...
# 26701              -1.764369               2.108745               3.624001
# 26702              -1.764369               2.108745               3.624001
# 26703              -1.764369               2.108745               3.624001
# 26704              -1.764369               2.108745               3.624001
# 26705              -1.764369               2.108745               3.624001
#
#        Solvent_2_EState_VSA5  Solvent_2_EState_VSA6  Solvent_2_EState_VSA9  \
# 0                  -0.393643               0.938131              -0.646882
# 1                  -0.393643              -0.567846              -0.646882
# 2                  -0.393643              -0.567846              -0.646882
# 3                  -0.393643              -0.567846              -0.646882
# 4                  -0.393643              -0.567846              -0.646882
# ...                      ...                    ...                    ...
# 26701              -0.393643              -0.567846               0.882785
# 26702              -0.393643              -0.567846               0.882785
# 26703              -0.393643              -0.567846               0.882785
# 26704              -0.393643              -0.567846               0.882785
# 26705              -0.393643              -0.567846               0.882785
#
#        Solvent_2_VSA_EState5  Solvent_2_NOCount  Solvent_2_fr_methoxy
# 0                  11.589770           0.034258             -0.100769
# 1                  -0.016175           0.034258             -0.100769
# 2                  -0.016175           0.034258             -0.100769
# 3                  -0.016175           0.034258             -0.100769
# 4                  -0.016175           0.034258             -0.100769
# ...                      ...                ...                   ...
# 26701              -0.016175           0.034258             -0.100769
# 26702              -0.016175           0.034258             -0.100769
# 26703              -0.016175           0.034258             -0.100769
# 26704              -0.016175           0.034258             -0.100769
# 26705              -0.016175           0.034258             -0.100769
#
# [26706 rows x 361 columns]

# %%
best_model.fit(literature_X_scaled, literature_Y)
# Out:
# LGBMRegressor()

# %%
with open('LightGBM.pkl', 'wb') as file:
    pickle.dump(best_model, file)

# %%
with open('LightGBM.pkl', 'rb') as file:
    best_model = pickle.load(file)

# %%
Y_pred = best_model.predict(X_lab)

# %%
summary = pd.DataFrame()

summary['Y_pred'] = Y_pred
summary['Y_exp'] = Y_lab.values
summary['Drug'] = lab['Drug'].values
summary['Temperature'] = lab['Temperature (K)'].values
summary['Solvent_mass_fraction'] = lab['Solvent_mass_fraction'].values
summary
# Out:
#       Y_pred     Y_exp                    Drug  Temperature  \
# 0  -0.514341  0.051018                 Aspirin    -0.248850
# 1   0.292757  1.143119  3-Indolepropionic acid    -0.248850
# 2  -0.553199 -0.285845  3-Indolepropionic acid     0.750123
# 3   0.544412  0.946698  3-Indolepropionic acid     0.750123
# 4   0.738544  1.313949  3-Indolepropionic acid     0.750123
# 5   0.395784  1.297876                 Aspirin    -0.248850
# 6   0.360061  1.001880                 Aspirin    -0.248850
# 7  -0.240697  0.407800                 Aspirin     0.750123
# 8   0.608087  1.242254                 Aspirin     0.750123
# 9  -0.892793 -0.732561  3-Indolepropionic acid    -0.248850
# 10  0.168286  0.653918  3-Indolepropionic acid    -0.248850
# 11  0.768538  0.011534               Celecoxib     0.750123
# 12  1.207176  1.386752           Acetaminophen     0.750123
# 13  0.926652  1.298532           Acetaminophen     0.750123
# 14 -0.109471  0.830016           Acetaminophen     0.750123
# 15  1.051001  1.280612           Acetaminophen    -0.248850
# 16  0.662801  1.165377           Acetaminophen    -0.248850
# 17 -0.436198  0.568126           Acetaminophen    -0.248850
# 18  1.070319  0.933291               Celecoxib     0.750123
# 19 -0.170478 -2.505811               Celecoxib     0.750123
# 20  0.942263  0.685046               Celecoxib    -0.248850
# 21  0.569028 -0.351141               Celecoxib    -0.248850
# 22 -0.417715 -3.061188               Celecoxib    -0.248850
# 23  0.688531  1.405768                 Aspirin     0.750123
#
#     Solvent_mass_fraction
# 0               -1.084714
# 1                0.935502
# 2               -1.084714
# 3               -0.074606
# 4                0.935502
# 5                0.935502
# 6               -0.074606
# 7               -1.084714
# 8               -0.074606
# 9               -1.084714
# 10              -0.074606
# 11              -0.074606
# 12               0.935502
# 13              -0.074606
# 14              -1.084714
# 15               0.935502
# 16              -0.074606
# 17              -1.084714
# 18               0.935502
# 19              -1.084714
# 20               0.935502
# 21              -0.074606
# 22              -1.084714
# 23               0.935502

# %%
drug_order = ['Celecoxib', 'Acetaminophen', '3-Indolepropionic acid', 'Aspirin']
summary['Drug'] = pd.Categorical(summary['Drug'], categories=drug_order, ordered=True)

summary_sorted = summary.sort_values(by=['Drug', 'Temperature', 'Solvent_mass_fraction'])

summary_sorted = summary_sorted.reset_index(drop = True)
summary_sorted
# Out:
#       Y_pred     Y_exp                    Drug  Temperature  \
# 0  -0.417715 -3.061188               Celecoxib    -0.248850
# 1   0.569028 -0.351141               Celecoxib    -0.248850
# 2   0.942263  0.685046               Celecoxib    -0.248850
# 3  -0.170478 -2.505811               Celecoxib     0.750123
# 4   0.768538  0.011534               Celecoxib     0.750123
# 5   1.070319  0.933291               Celecoxib     0.750123
# 6  -0.436198  0.568126           Acetaminophen    -0.248850
# 7   0.662801  1.165377           Acetaminophen    -0.248850
# 8   1.051001  1.280612           Acetaminophen    -0.248850
# 9  -0.109471  0.830016           Acetaminophen     0.750123
# 10  0.926652  1.298532           Acetaminophen     0.750123
# 11  1.207176  1.386752           Acetaminophen     0.750123
# 12 -0.892793 -0.732561  3-Indolepropionic acid    -0.248850
# 13  0.168286  0.653918  3-Indolepropionic acid    -0.248850
# 14  0.292757  1.143119  3-Indolepropionic acid    -0.248850
# 15 -0.553199 -0.285845  3-Indolepropionic acid     0.750123
# 16  0.544412  0.946698  3-Indolepropionic acid     0.750123
# 17  0.738544  1.313949  3-Indolepropionic acid     0.750123
# 18 -0.514341  0.051018                 Aspirin    -0.248850
# 19  0.360061  1.001880                 Aspirin    -0.248850
# 20  0.395784  1.297876                 Aspirin    -0.248850
# 21 -0.240697  0.407800                 Aspirin     0.750123
# 22  0.608087  1.242254                 Aspirin     0.750123
# 23  0.688531  1.405768                 Aspirin     0.750123
#
#     Solvent_mass_fraction
# 0               -1.084714
# 1               -0.074606
# 2                0.935502
# 3               -1.084714
# 4               -0.074606
# 5                0.935502
# 6               -1.084714
# 7               -0.074606
# 8                0.935502
# 9               -1.084714
# 10              -0.074606
# 11               0.935502
# 12              -1.084714
# 13              -0.074606
# 14               0.935502
# 15              -1.084714
# 16              -0.074606
# 17               0.935502
# 18              -1.084714
# 19              -0.074606
# 20               0.935502
# 21              -1.084714
# 22              -0.074606
# 23               0.935502

# %%
file_path = "../Exp_1_Raw_Dataset/Raw_dataset_dataset_20240705.csv"
original_data = pd.read_csv(file_path)

lab_X = original_data[original_data['Type'] == 'Lab']
literature_X = original_data[original_data['Type'] != 'Lab']

# %%
literature_X[['Type']].describe()
# Out:
#          Type
# count   26706
# unique      2
# top     Train
# freq    19896

# %%
cols_of_interest = ['Drug','Drug_ExactMolWt', 'Drug_Melting_temp (K)']

# %%
experiment_STD = [0.026547199, 0.007765518, 0.00609362, 0.011489668, 0.009077589, 0.004943748,
                 0.009819746, 0.007260406, 0.020924193, 0.008093572, 0.005818861, 0.009665102,
                0.016553364, 0.008737235, 0.005338153, 0.021981287, 0.023570222, 0.012345814,
                 0.004954186, 0.007637141, 0.003202658, 0.012285287, 0.0108218, 0.005967770]

# %%
plot = lab_X[['Drug','Solvent_mass_fraction','Temperature (K)','LogS']]
plot['LogS_SD'] = experiment_STD
plot['Y_pred'] = summary_sorted['Y_pred'].values

plot['AE'] = abs(plot['LogS'] - plot['Y_pred'])
plot
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          Drug  Solvent_mass_fraction  Temperature (K)  \
# 26706               Celecoxib                    0.2           298.15
# 26707               Celecoxib                    0.5           298.15
# 26708               Celecoxib                    0.8           298.15
# 26709               Celecoxib                    0.2           313.15
# 26710               Celecoxib                    0.5           313.15
# 26711               Celecoxib                    0.8           313.15
# 26712           Acetaminophen                    0.2           298.15
# 26713           Acetaminophen                    0.5           298.15
# 26714           Acetaminophen                    0.8           298.15
# 26715           Acetaminophen                    0.2           313.15
# 26716           Acetaminophen                    0.5           313.15
# 26717           Acetaminophen                    0.8           313.15
# 26718  3-Indolepropionic acid                    0.2           298.15
# 26719  3-Indolepropionic acid                    0.5           298.15
# 26720  3-Indolepropionic acid                    0.8           298.15
# 26721  3-Indolepropionic acid                    0.2           313.15
# 26722  3-Indolepropionic acid                    0.5           313.15
# 26723  3-Indolepropionic acid                    0.8           313.15
# 26724                 Aspirin                    0.2           298.15
# 26725                 Aspirin                    0.5           298.15
# 26726                 Aspirin                    0.8           298.15
# 26727                 Aspirin                    0.2           313.15
# 26728                 Aspirin                    0.5           313.15
# 26729                 Aspirin                    0.8           313.15
#
#            LogS   LogS_SD    Y_pred        AE
# 26706 -3.061188  0.026547 -0.417715  2.643473
# 26707 -0.351141  0.007766  0.569028  0.920168
# 26708  0.685046  0.006094  0.942263  0.257216
# 26709 -2.505811  0.011490 -0.170478  2.335333
# 26710  0.011534  0.009078  0.768538  0.757004
# 26711  0.933291  0.004944  1.070319  0.137028
# 26712  0.568126  0.009820 -0.436198  1.004324
# 26713  1.165377  0.007260  0.662801  0.502576
# 26714  1.280612  0.020924  1.051001  0.229611
# 26715  0.830016  0.008094 -0.109471  0.939487
# 26716  1.298532  0.005819  0.926652  0.371880
# 26717  1.386752  0.009665  1.207176  0.179577
# 26718 -0.732561  0.016553 -0.892793  0.160232
# 26719  0.653918  0.008737  0.168286  0.485632
# 26720  1.143119  0.005338  0.292757  0.850363
# 26721 -0.285845  0.021981 -0.553199  0.267354
# 26722  0.946698  0.023570  0.544412  0.402286
# 26723  1.313949  0.012346  0.738544  0.575405
# 26724  0.051018  0.004954 -0.514341  0.565359
# 26725  1.001880  0.007637  0.360061  0.641819
# 26726  1.297876  0.003203  0.395784  0.902092
# 26727  0.407800  0.012285 -0.240697  0.648497
# 26728  1.242254  0.010822  0.608087  0.634167
# 26729  1.405768  0.005968  0.688531  0.717237

# %%
ACM = plot[plot['Drug'] == 'Acetaminophen']

CXB = plot[plot['Drug'] == 'Celecoxib']

IPA = plot[plot['Drug'] == '3-Indolepropionic acid']

ASA = plot[plot['Drug'] == 'Aspirin']

# %%
def exp(df, ax, color, drug, ann):

    unique_temperatures = df['Temperature (K)'].unique()
    fontsize = 12

    width = 0.35  
    x = np.arange(len(df['Solvent_mass_fraction'].unique()))
    
    for i, temp in enumerate(unique_temperatures):
        subset = df[df['Temperature (K)'] == temp]
        
        
        bar_color = color
        
        
        ax.bar(x + i * width, subset['LogS'], width=width, label=f'Temperature {temp} K', color=bar_color, edgecolor='black', linewidth=0.5)
        
        
        if temp == 313.15:
            ax.bar(x + i * width, subset['LogS'], width=width, hatch='///', edgecolor='black', fill=False, linewidth=0)

    
    for i, temp in enumerate(unique_temperatures):
        subset = df[df['Temperature (K)'] == temp]
        ax.errorbar(x + i * width, subset['LogS'], yerr=subset['LogS_SD'], fmt='none', color='k', capsize=5)

    ax.set_xlabel('Ethanol Fraction')
    ax.set_ylabel('Experimental LogS')
    ax.set_title(drug)  
    ax.set_xticks(x + width * (len(unique_temperatures) - 1) / 2)
    ax.set_xticklabels(df['Solvent_mass_fraction'].unique())
    
    
    ax.legend().set_visible(False)
    
    
    ax.axhline(y=0, color='black', linewidth=0.5)
    
    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
def metrics(df, ax, color, ann):
    
    fontsize = 12
    mae = mean_absolute_error(df['LogS'], df['Y_pred'])
    medae = median_absolute_error(df['LogS'], df['Y_pred'])
    mse = mean_squared_error(df['LogS'], df['Y_pred'])
    rmse = np.sqrt(mse)
    pearson_r = pearsonr(df['LogS'], df['Y_pred'])[0]
    spearman_r = spearmanr(df['LogS'], df['Y_pred'])[0]
    
    metrics = ['MAE', 'MedAE', 'RMSE', 'MSE', 'PCC', 'SCC']
    values = [mae, medae, rmse, mse, pearson_r, spearman_r]

    bars = ax.bar(metrics, values, color=color, edgecolor='black', linewidth=0.5)
    ax.set_xlabel('')
    ax.set_ylabel('Values')
    ax.set_ylim(0, 3.3)
    ax.set_title('')
    
    for bar in bars:
        height = bar.get_height()
        if height >= 0:
            ax.text(bar.get_x() + bar.get_width() / 2, height, 
                    f'{height:.2f}', ha='center', va='bottom')
        else:
            ax.text(bar.get_x() + bar.get_width() / 2, 0, 
                    f'{height:.2f}', ha='center', va='bottom')

    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
def scatter(df, ax, color, ann):
    fontsize = 12
    
    
    ax.scatter(df['LogS'], df['Y_pred'], color=color)

    
    max_limit = max(df['LogS'].max(), df['Y_pred'].max())
    min_limit = min(df['LogS'].min(), df['Y_pred'].min())
    ax.set_xlim(min_limit-0.2, max_limit+0.2)
    ax.set_ylim(min_limit-0.2, max_limit+0.2)

    
    ax.set_xlabel('Actual LogS')
    ax.set_ylabel('Predicted LogS')
    ax.set_title(df['Drug'].iloc[0])  

    
    ax.annotate(ann, xy=(0, 1.08), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
# colors

acm_color = 'dimgray'
ipa_color = red
cxb_color = blue
asa_color = yellow

fig = plt.figure(figsize=(16, 8))
grid = plt.GridSpec(2, 4, wspace=0.3, hspace=0.3)


ax1 = fig.add_subplot(grid[0, 0])
exp(df = ASA, ax = ax1, color = asa_color, ann = 'a)', drug = 'Aspirin')

ax2 = fig.add_subplot(grid[0, 1])
exp(df = ACM, ax = ax2, color = acm_color, ann = 'b)', drug = 'Acetaminophen')


ax3 = fig.add_subplot(grid[0,2])
exp(df = IPA, ax = ax3, color = ipa_color, ann = 'c)', drug = '3-Indolepropionic acid')


ax4 = fig.add_subplot(grid[0, 3])
exp(df = CXB, ax = ax4, color = cxb_color, ann = 'd)', drug = 'Celecoxib')



ax5 = fig.add_subplot(grid[1, 0])
metrics(df = ASA, ax = ax5, color = asa_color, ann = 'e)')

ax6 = fig.add_subplot(grid[1, 1])
metrics(df = ACM, ax = ax6, color = acm_color, ann = 'f)')


ax7 = fig.add_subplot(grid[1,2])
metrics(df = IPA, ax = ax7, color = ipa_color, ann = 'g)')


ax8 = fig.add_subplot(grid[1, 3])
metrics(df = CXB, ax = ax8, color = cxb_color, ann = 'h)')






fig.patch.set(facecolor='none')

plt.tight_layout()

fig.canvas.print_figure('Figure_5_Model_Validation' + data_for + '.png', dpi=600)


plt.show()
# Out:
# This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
best_model
# Out:
# LGBMRegressor()

# %%
def plot_feature_importance_xgb(booster, ax, selected, ann, importance_type='weight', top_n=15, filter_drug_features=True):
    fontsize = 12
    
    
    importances = booster.get_score(importance_type=importance_type)
    feature_names = list(importances.keys())
    importance_values = list(importances.values())

    
    importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance_values})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    
    if filter_drug_features:
        importance_df = importance_df[importance_df['Feature'].str.startswith('Drug_')]

    
    importance_df_top_n = importance_df.head(top_n)

    
    palette_choice = ['lightcoral' if feature in selected else blue for feature in importance_df_top_n['Feature']]
    bars = sns.barplot(x='Importance', y='Feature', data=importance_df_top_n, ax=ax, palette=palette_choice, edgecolor='black')
    
    
    ax.annotate(ann, xy=(0, 1.025), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)
    ax.set_title("", fontsize=fontsize)
    
    
    ax.set_xlabel("Feature Importance", fontsize=fontsize)
    ax.set_ylabel("", fontsize=fontsize)

    
    ax.tick_params(axis='x', which='major', labelsize=fontsize)
    ax.tick_params(axis='x', which='minor', labelsize=fontsize)
    ax.tick_params(axis='y', which='major', labelsize=fontsize)
    ax.tick_params(axis='y', which='minor', labelsize=fontsize)
    
    return importance_df_top_n

# %%
lab_X['Type'] = lab_X['Drug']
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def plot_distribution_with_labels_on_trend(ann, prop, ax, show_legend=False, legend_pos = (-0.08, 1.28), ncol = 2):
    fontsize = 12
    
    
    sns.boxplot(y=literature_X[prop], color='lightcoral', fliersize=1, ax=ax)
    
    
    unique_drugs = ['Aspirin','Acetaminophen', '3-Indolepropionic acid', 'Celecoxib']
    colors = [yellow, black, red, blue]
    
    drug_color_map = dict(zip(unique_drugs, colors))
    
    x_positions = np.linspace(-0.0, 0.0, len(unique_drugs))
    
    
    legend_handles = []
    
    
    for idx, drug in enumerate(unique_drugs):
        drug_data = lab_X[lab_X["Drug"] == drug]  
        scatter = ax.scatter([x_positions[idx]] * len(drug_data), drug_data[prop], 
                             color=drug_color_map[drug], label=drug, 
                             alpha=1.0, edgecolor='black', linewidth=0.8, s=180,
                             zorder=10)  
        legend_handles.append(scatter)
    
    ax.set_ylabel('', fontsize=fontsize)
    ax.set_title(prop, fontsize=fontsize)
    
    
    ax.tick_params(axis='both', which='major', labelsize=fontsize)
    ax.tick_params(axis='both', which='minor', labelsize=fontsize)
    
    if show_legend:
        ax.legend(handles=legend_handles, title='', loc='upper left', bbox_to_anchor=legend_pos, frameon=False, ncol=ncol, fontsize=fontsize+1)
        
    ax.annotate(ann, xy=(0, 1.05), xycoords="axes fraction", va="top", ha="left", fontsize=fontsize)

# %%
fig = plt.figure(figsize=(18, 12))
grid = gridspec.GridSpec(2, 4, fig, wspace=0.2, hspace=0.1)
selected=['Drug_MinPartialCharge', 'Drug_MinEStateIndex', 'Drug_MaxEStateIndex', 'Drug_MaxPartialCharge']


ax1 = fig.add_subplot(grid[0:2, 0:2])
important_features = plot_feature_importance_xgb(booster=best_model.get_booster(), ax=ax1,  selected=selected, ann = 'a)')

ax2 = fig.add_subplot(grid[0, 2])
plot_distribution_with_labels_on_trend(ann = 'b)',prop='Drug_MinPartialCharge', ax=ax2, legend_pos = (0.25, 1.25), ncol = 2, show_legend=True)


ax3 = fig.add_subplot(grid[0, 3])
plot_distribution_with_labels_on_trend(ann = 'c)',prop='Drug_MinEStateIndex', ax=ax3, show_legend=False)



ax4 = fig.add_subplot(grid[1, 2])
plot_distribution_with_labels_on_trend(ann = 'd)',prop='Drug_MaxEStateIndex', ax=ax4, show_legend=False)



ax5 = fig.add_subplot(grid[1, 3])
plot_distribution_with_labels_on_trend(ann = 'e)',prop='Drug_MaxPartialCharge', ax=ax5, show_legend=False)


fig.patch.set(facecolor='none')



fig.canvas.print_figure('Figure_6_Model_Interpretation.png', dpi=600)


plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(18, 12))
fontsize = 24

all_important_features = plot_feature_importance_xgb(booster=best_model.get_booster(), ax=ax1, selected='', ann='', top_n=20, filter_drug_features=False)


ax1.set_xlabel('Feature Importance', fontsize=fontsize)  
ax1.set_ylabel('', fontsize=fontsize)  
ax1.tick_params(axis='x', labelsize=fontsize)  
ax1.tick_params(axis='y', labelsize=fontsize)  
plt.tight_layout()

fig.patch.set(facecolor='none')
fig.savefig('Figure_SI_top 20 features.png', dpi=300)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 4
#       1 fig, ax1 = plt.subplots(figsize=(18, 12))
#       2 fontsize = 24
# ----> 4 all_important_features = plot_feature_importance_xgb(booster=best_model.get_booster(), ax=ax1, selected='', ann='', top_n=20, filter_drug_features=False)
#       7 ax1.set_xlabel('Feature Importance', fontsize=fontsize)
#       8 ax1.set_ylabel('', fontsize=fontsize)
#
# AttributeError: 'DecisionTreeRegressor' object has no attribute 'get_booster'

# %%
important_features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 important_features
#
# NameError: name 'important_features' is not defined

# %%
fig = plt.figure(figsize=(25, 15))  
gs = gridspec.GridSpec(3, 5, fig) 


for i, feature in enumerate(important_features['Feature']):
    row = i // 5  
    col = i % 5   
    ax = fig.add_subplot(gs[row, col])

    
    plot_distribution_with_labels_on_trend(
        ann=f'({chr(97+i)})',  
        prop=feature,
        ax=ax,
        show_legend=(i==14), legend_pos = (-3, 3.65), ncol = 4  
    )

plt.tight_layout()


fig.patch.set(facecolor='none')
fig.canvas.print_figure('Figure_SI_All_feture_distribution.png', dpi=600)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       1 fig = plt.figure(figsize=(25, 15))
#       2 gs = gridspec.GridSpec(3, 5, fig)
# ----> 5 for i, feature in enumerate(important_features['Feature']):
#       6     row = i // 5
#       7     col = i % 5
#
# NameError: name 'important_features' is not defined

# %%
def print_summary_with_deviation_count():
    
    quantiles = literature_X.quantile([0.25, 0.75])
    
    
    unique_drugs = ['Acetaminophen', '3-Indolepropionic acid', 'Celecoxib', 'Aspirin']
    summary = []
    
    for feature in important_features['Feature']:
        Q1, Q3 = quantiles[feature].values
        for drug in unique_drugs:
            drug_data = lab_X[lab_X["Drug"] == drug]
            drug_feature_values = drug_data[feature]
            
            
            below_Q1 = drug_feature_values < Q1
            above_Q3 = drug_feature_values > Q3
            
            deviation = "deviates" if any(below_Q1) or any(above_Q3) else "does not deviate"
            
            summary.append([drug, feature, deviation])
    
    
    summary_df = pd.DataFrame(summary, columns=['Drug', 'Feature', 'Deviation'])
    summary_pivot = summary_df.pivot(index='Drug', columns='Feature', values='Deviation')
    
    
    deviation_counts = summary_df.groupby('Drug')['Deviation'].apply(lambda x: (x == "deviates").sum()).reset_index(name='Deviation Count')
    
    
    summary_with_counts = summary_pivot.merge(deviation_counts, left_on='Drug', right_on='Drug')
    summary_with_counts.set_index('Drug', inplace=True)
    
    
    columns_order = ['Deviation Count'] + [col for col in summary_with_counts if col != 'Deviation Count']
    summary_with_counts = summary_with_counts[columns_order]
    
    return summary_with_counts


summary_with_counts = print_summary_with_deviation_count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 41
#      36     summary_with_counts = summary_with_counts[columns_order]
#      38     return summary_with_counts
# ---> 41 summary_with_counts = print_summary_with_deviation_count()
#
# Cell In[40], line 9, in print_summary_with_deviation_count()
#       6 unique_drugs = ['Acetaminophen', '3-Indolepropionic acid', 'Celecoxib', 'Aspirin']
#       7 summary = []
# ----> 9 for feature in important_features['Feature']:
#      10     Q1, Q3 = quantiles[feature].values
#      11     for drug in unique_drugs:
#
# NameError: name 'important_features' is not defined

# %%
summary_with_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 summary_with_counts
#
# NameError: name 'summary_with_counts' is not defined

# %%
literature_X
# Out:
#                           Drug          Solvent_1  Solvent_mass_fraction  \
# 0      Guanidine hydrochloride  Dimethylformamide                 0.1001
# 1      Guanidine hydrochloride  Dimethylformamide                 0.1001
# 2      Guanidine hydrochloride  Dimethylformamide                 0.1001
# 3      Guanidine hydrochloride  Dimethylformamide                 0.1001
# 4      Guanidine hydrochloride  Dimethylformamide                 0.1001
# ...                        ...                ...                    ...
# 27252              Carbendazim         1-Propanol                 1.0000
# 27253              Carbendazim         1-Propanol                 1.0000
# 27254              Carbendazim         1-Propanol                 1.0000
# 27255              Carbendazim         1-Propanol                 1.0000
# 27256              Carbendazim         1-Propanol                 1.0000
#
#        Solvent_mol_fraction   Solvent_2  Temperature (K)  \
# 0                  0.083785  1-Propanol           278.15
# 1                  0.083785  1-Propanol           283.15
# 2                  0.083785  1-Propanol           288.15
# 3                  0.083785  1-Propanol           293.15
# 4                  0.083785  1-Propanol           298.15
# ...                     ...         ...              ...
# 27252              1.000000       Water           298.15
# 27253              1.000000       Water           303.15
# 27254              1.000000       Water           308.15
# 27255              1.000000       Water           313.15
# 27256              1.000000       Water           318.15
#
#        Drug_Melting_temp (K)                Drug_SMILES  Drug_Maccs_1  \
# 0                     451.15                 Cl.N=C(N)N             0
# 1                     451.15                 Cl.N=C(N)N             0
# 2                     451.15                 Cl.N=C(N)N             0
# 3                     451.15                 Cl.N=C(N)N             0
# 4                     451.15                 Cl.N=C(N)N             0
# ...                      ...                        ...           ...
# 27252                 573.15  O=C(OC)NC1=NC=2C=CC=CC2N1             0
# 27253                 573.15  O=C(OC)NC1=NC=2C=CC=CC2N1             0
# 27254                 573.15  O=C(OC)NC1=NC=2C=CC=CC2N1             0
# 27255                 573.15  O=C(OC)NC1=NC=2C=CC=CC2N1             0
# 27256                 573.15  O=C(OC)NC1=NC=2C=CC=CC2N1             0
#
#        Drug_Maccs_2  ...  Solvent_2_fr_thiazole  Solvent_2_fr_thiocyan  \
# 0                 0  ...                      0                      0
# 1                 0  ...                      0                      0
# 2                 0  ...                      0                      0
# 3                 0  ...                      0                      0
# 4                 0  ...                      0                      0
# ...             ...  ...                    ...                    ...
# 27252             0  ...                      0                      0
# 27253             0  ...                      0                      0
# 27254             0  ...                      0                      0
# 27255             0  ...                      0                      0
# 27256             0  ...                      0                      0
#
#        Solvent_2_fr_thiophene  Solvent_2_fr_unbrch_alkane  Solvent_2_fr_urea  \
# 0                           0                           0                  0
# 1                           0                           0                  0
# 2                           0                           0                  0
# 3                           0                           0                  0
# 4                           0                           0                  0
# ...                       ...                         ...                ...
# 27252                       0                           0                  0
# 27253                       0                           0                  0
# 27254                       0                           0                  0
# 27255                       0                           0                  0
# 27256                       0                           0                  0
#
#        Solubility (g/100g)      LogS           Class  \
# 0                10.385820  1.016441    (1.01, 1.99]
# 1                11.483782  1.060085    (1.01, 1.99]
# 2                12.609713  1.100705    (1.01, 1.99]
# 3                13.442009  1.128464    (1.01, 1.99]
# 4                14.409071  1.158636    (1.01, 1.99]
# ...                    ...       ...             ...
# 27252             0.005879 -2.230692  [-5.48, -0.42]
# 27253             0.008675 -2.061717  [-5.48, -0.42]
# 27254             0.012842 -1.891356  [-5.48, -0.42]
# 27255             0.018530 -1.732135  [-5.48, -0.42]
# 27256             0.026519 -1.576445  [-5.48, -0.42]
#
#                                      Drug-solvent system   Type
# 0      Guanidine hydrochloride-1-Propanol/Dimethylfor...  Train
# 1      Guanidine hydrochloride-1-Propanol/Dimethylfor...  Train
# 2      Guanidine hydrochloride-1-Propanol/Dimethylfor...  Train
# 3      Guanidine hydrochloride-1-Propanol/Dimethylfor...  Train
# 4      Guanidine hydrochloride-1-Propanol/Dimethylfor...  Train
# ...                                                  ...    ...
# 27252                       Carbendazim-1-Propanol/Water  Train
# 27253                       Carbendazim-1-Propanol/Water  Train
# 27254                       Carbendazim-1-Propanol/Water  Train
# 27255                       Carbendazim-1-Propanol/Water  Train
# 27256                       Carbendazim-1-Propanol/Water  Train
#
# [27257 rows x 1137 columns]

# %%
lab_X
# Out:
#                          Drug Solvent_1  Solvent_mass_fraction  \
# 27257               Celecoxib   Ethanol                    0.2
# 27258               Celecoxib   Ethanol                    0.5
# 27259               Celecoxib   Ethanol                    0.8
# 27260               Celecoxib   Ethanol                    0.2
# 27261               Celecoxib   Ethanol                    0.5
# 27262               Celecoxib   Ethanol                    0.8
# 27263           Acetaminophen   Ethanol                    0.2
# 27264           Acetaminophen   Ethanol                    0.5
# 27265           Acetaminophen   Ethanol                    0.8
# 27266           Acetaminophen   Ethanol                    0.2
# 27267           Acetaminophen   Ethanol                    0.5
# 27268           Acetaminophen   Ethanol                    0.8
# 27269  3-Indolepropionic acid   Ethanol                    0.2
# 27270  3-Indolepropionic acid   Ethanol                    0.5
# 27271  3-Indolepropionic acid   Ethanol                    0.8
# 27272  3-Indolepropionic acid   Ethanol                    0.2
# 27273  3-Indolepropionic acid   Ethanol                    0.5
# 27274  3-Indolepropionic acid   Ethanol                    0.8
# 27275                 Aspirin   Ethanol                    0.2
# 27276                 Aspirin   Ethanol                    0.5
# 27277                 Aspirin   Ethanol                    0.8
# 27278                 Aspirin   Ethanol                    0.2
# 27279                 Aspirin   Ethanol                    0.5
# 27280                 Aspirin   Ethanol                    0.8
#
#        Solvent_mol_fraction Solvent_2  Temperature (K)  Drug_Melting_temp (K)  \
# 27257              0.089083     Water           298.15                 431.15
# 27258              0.281185     Water           298.15                 431.15
# 27259              0.610093     Water           298.15                 431.15
# 27260              0.089083     Water           313.15                 431.15
# 27261              0.281185     Water           313.15                 431.15
# 27262              0.610093     Water           313.15                 431.15
# 27263              0.089083     Water           298.15                 442.90
# 27264              0.281185     Water           298.15                 442.90
# 27265              0.610093     Water           298.15                 442.90
# 27266              0.089083     Water           313.15                 442.90
# 27267              0.281185     Water           313.15                 442.90
# 27268              0.610093     Water           313.15                 442.90
# 27269              0.089083     Water           298.15                 407.65
# 27270              0.281185     Water           298.15                 407.65
# 27271              0.610093     Water           298.15                 407.65
# 27272              0.089083     Water           313.15                 407.65
# 27273              0.281185     Water           313.15                 407.65
# 27274              0.610093     Water           313.15                 407.65
# 27275              0.089083     Water           298.15                 408.15
# 27276              0.281185     Water           298.15                 408.15
# 27277              0.610093     Water           298.15                 408.15
# 27278              0.089083     Water           313.15                 408.15
# 27279              0.281185     Water           313.15                 408.15
# 27280              0.610093     Water           313.15                 408.15
#
#                                              Drug_SMILES  Drug_Maccs_1  \
# 27257  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27258  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27259  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27260  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27261  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27262  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27263                              O=C(NC1=CC=C(O)C=C1)C             0
# 27264                              O=C(NC1=CC=C(O)C=C1)C             0
# 27265                              O=C(NC1=CC=C(O)C=C1)C             0
# 27266                              O=C(NC1=CC=C(O)C=C1)C             0
# 27267                              O=C(NC1=CC=C(O)C=C1)C             0
# 27268                              O=C(NC1=CC=C(O)C=C1)C             0
# 27269                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27270                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27271                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27272                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27273                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27274                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27275                           O=C(O)C=1C=CC=CC1OC(=O)C             0
# 27276                           O=C(O)C=1C=CC=CC1OC(=O)C             0
# 27277                           O=C(O)C=1C=CC=CC1OC(=O)C             0
# 27278                           O=C(O)C=1C=CC=CC1OC(=O)C             0
# 27279                           O=C(O)C=1C=CC=CC1OC(=O)C             0
# 27280                           O=C(O)C=1C=CC=CC1OC(=O)C             0
#
#        Drug_Maccs_2  ...  Solvent_2_fr_thiazole  Solvent_2_fr_thiocyan  \
# 27257             0  ...                      0                      0
# 27258             0  ...                      0                      0
# 27259             0  ...                      0                      0
# 27260             0  ...                      0                      0
# 27261             0  ...                      0                      0
# 27262             0  ...                      0                      0
# 27263             0  ...                      0                      0
# 27264             0  ...                      0                      0
# 27265             0  ...                      0                      0
# 27266             0  ...                      0                      0
# 27267             0  ...                      0                      0
# 27268             0  ...                      0                      0
# 27269             0  ...                      0                      0
# 27270             0  ...                      0                      0
# 27271             0  ...                      0                      0
# 27272             0  ...                      0                      0
# 27273             0  ...                      0                      0
# 27274             0  ...                      0                      0
# 27275             0  ...                      0                      0
# 27276             0  ...                      0                      0
# 27277             0  ...                      0                      0
# 27278             0  ...                      0                      0
# 27279             0  ...                      0                      0
# 27280             0  ...                      0                      0
#
#        Solvent_2_fr_thiophene  Solvent_2_fr_unbrch_alkane  Solvent_2_fr_urea  \
# 27257                       0                           0                  0
# 27258                       0                           0                  0
# 27259                       0                           0                  0
# 27260                       0                           0                  0
# 27261                       0                           0                  0
# 27262                       0                           0                  0
# 27263                       0                           0                  0
# 27264                       0                           0                  0
# 27265                       0                           0                  0
# 27266                       0                           0                  0
# 27267                       0                           0                  0
# 27268                       0                           0                  0
# 27269                       0                           0                  0
# 27270                       0                           0                  0
# 27271                       0                           0                  0
# 27272                       0                           0                  0
# 27273                       0                           0                  0
# 27274                       0                           0                  0
# 27275                       0                           0                  0
# 27276                       0                           0                  0
# 27277                       0                           0                  0
# 27278                       0                           0                  0
# 27279                       0                           0                  0
# 27280                       0                           0                  0
#
#        Solubility (g/100g)      LogS  Class  \
# 27257             0.000869 -3.061188    NaN
# 27258             0.445512 -0.351141    NaN
# 27259             4.842238  0.685046    NaN
# 27260             0.003120 -2.505811    NaN
# 27261             1.026914  0.011534    NaN
# 27262             8.576122  0.933291    NaN
# 27263             3.699358  0.568126    NaN
# 27264            14.634461  1.165377    NaN
# 27265            19.081476  1.280612    NaN
# 27266             6.761074  0.830016    NaN
# 27267            19.885275  1.298532    NaN
# 27268            24.364208  1.386752    NaN
# 27269             0.185114 -0.732561    NaN
# 27270             4.507317  0.653918    NaN
# 27271            13.903345  1.143119    NaN
# 27272             0.517792 -0.285845    NaN
# 27273             8.844998  0.946698    NaN
# 27274            20.603882  1.313949    NaN
# 27275             1.124651  0.051018    NaN
# 27276            10.043375  1.001880    NaN
# 27277            19.855270  1.297876    NaN
# 27278             2.557410  0.407800    NaN
# 27279            17.468437  1.242254    NaN
# 27280            25.454687  1.405768    NaN
#
#                         Drug-solvent system                    Type
# 27257               Celecoxib-Ethanol/Water               Celecoxib
# 27258               Celecoxib-Ethanol/Water               Celecoxib
# 27259               Celecoxib-Ethanol/Water               Celecoxib
# 27260               Celecoxib-Ethanol/Water               Celecoxib
# 27261               Celecoxib-Ethanol/Water               Celecoxib
# 27262               Celecoxib-Ethanol/Water               Celecoxib
# 27263           Acetaminophen-Ethanol/Water           Acetaminophen
# 27264           Acetaminophen-Ethanol/Water           Acetaminophen
# 27265           Acetaminophen-Ethanol/Water           Acetaminophen
# 27266           Acetaminophen-Ethanol/Water           Acetaminophen
# 27267           Acetaminophen-Ethanol/Water           Acetaminophen
# 27268           Acetaminophen-Ethanol/Water           Acetaminophen
# 27269  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27270  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27271  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27272  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27273  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27274  3-Indolepropionic acid-Ethanol/Water  3-Indolepropionic acid
# 27275                 Aspirin-Ethanol/Water                 Aspirin
# 27276                 Aspirin-Ethanol/Water                 Aspirin
# 27277                 Aspirin-Ethanol/Water                 Aspirin
# 27278                 Aspirin-Ethanol/Water                 Aspirin
# 27279                 Aspirin-Ethanol/Water                 Aspirin
# 27280                 Aspirin-Ethanol/Water                 Aspirin
#
# [24 rows x 1137 columns]

# %%
def filter_drug_columns(df):
    # 选择列名以"Drug"开头的列
    drug_columns = [col for col in df.columns if col.startswith('Drug')]
    # 创建新的DataFrame，只包含这些列
    new_df = df[drug_columns]
    new_df = new_df.drop(['Drug-solvent system'], axis = 1)
    new_df = new_df.drop_duplicates()

    # cols_to_drop = ['Solvent_1', 'Solvent_2', 'Solubility (g/100g)', 'Type', 'Class', 'Drug-solvent system', 'LogS']
    # new_df = df.drop(cols_to_drop, axis=1)

    
    return new_df

# %%
drug_lab = filter_drug_columns(lab_X)
drug_lab
# Out:
#                          Drug  Drug_Melting_temp (K)  \
# 27257               Celecoxib                 431.15
# 27263           Acetaminophen                 442.90
# 27269  3-Indolepropionic acid                 407.65
# 27275                 Aspirin                 408.15
#
#                                              Drug_SMILES  Drug_Maccs_1  \
# 27257  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...             0
# 27263                              O=C(NC1=CC=C(O)C=C1)C             0
# 27269                          O=C(O)CCC1=CNC=2C=CC=CC21             0
# 27275                           O=C(O)C=1C=CC=CC1OC(=O)C             0
#
#        Drug_Maccs_2  Drug_Maccs_3  Drug_Maccs_4  Drug_Maccs_5  Drug_Maccs_6  \
# 27257             0             0             0             0             0
# 27263             0             0             0             0             0
# 27269             0             0             0             0             0
# 27275             0             0             0             0             0
#
#        Drug_Maccs_7  ...  Drug_fr_sulfide  Drug_fr_sulfonamd  Drug_fr_sulfone  \
# 27257             0  ...                0                  1                0
# 27263             0  ...                0                  0                0
# 27269             0  ...                0                  0                0
# 27275             0  ...                0                  0                0
#
#        Drug_fr_term_acetylene  Drug_fr_tetrazole  Drug_fr_thiazole  \
# 27257                       0                  0                 0
# 27263                       0                  0                 0
# 27269                       0                  0                 0
# 27275                       0                  0                 0
#
#        Drug_fr_thiocyan  Drug_fr_thiophene  Drug_fr_unbrch_alkane  \
# 27257                 0                  0                      0
# 27263                 0                  0                      0
# 27269                 0                  0                      0
# 27275                 0                  0                      0
#
#        Drug_fr_urea
# 27257             0
# 27263             0
# 27269             0
# 27275             0
#
# [4 rows x 377 columns]

# %%
drug_literature = filter_drug_columns(literature_X)
drug_literature
# Out:
#                                        Drug  Drug_Melting_temp (K)  \
# 0                   Guanidine hydrochloride                451.150
# 200               Glucosamine hydrochloride                491.007
# 299                2-Amino-6-chloropyrazine                426.150
# 659                        Thiamine nitrate                471.150
# 843                            Aripiprazole                383.150
# ...                                     ...                    ...
# 23781  2-Chloro-3-(trifluoromethyl)pyridine                311.150
# 23889                          Dipyridamole                436.150
# 24057                            Artesunate                414.150
# 24381                           Carbendazim                573.150
# 24705                           Vinpocetine                423.150
#
#                                              Drug_SMILES  Drug_Maccs_1  \
# 0                                             Cl.N=C(N)N             0
# 200                             Cl.O=CC(N)C(O)C(O)C(O)CO             0
# 299                                     ClC=1N=C(N)C=NC1             0
# 659       O=N(=O)[O-].OCCC=1SC=[N+](C1C)CC2=CN=C(N=C2N)C             0
# 843    O=C1NC2=CC(OCCCCN3CCN(C=4C=CC=C(Cl)C4Cl)CC3)=C...             0
# ...                                                  ...           ...
# 23781                              FC(F)(F)C1=CC=CN=C1Cl             0
# 23889  OCCN(C=1N=C2C(N=C(N=C2N3CCCCC3)N(CCO)CCO)=C(N1...             0
# 24057    O=C(O)CCC(=O)OC1OC2OC3(OOC24C(CC3)C(C)CCC4C1C)C             0
# 24381                          O=C(OC)NC1=NC=2C=CC=CC2N1             0
# 24705     O=C(OCC)C1=CC2(CC)CCCN3CCC=4C=5C=CC=CC5N1C4C32             0
#
#        Drug_Maccs_2  Drug_Maccs_3  Drug_Maccs_4  Drug_Maccs_5  Drug_Maccs_6  \
# 0                 0             0             0             0             0
# 200               0             0             0             0             0
# 299               0             0             0             0             0
# 659               0             0             0             0             0
# 843               0             0             0             0             0
# ...             ...           ...           ...           ...           ...
# 23781             0             0             0             0             0
# 23889             0             0             0             0             0
# 24057             0             0             0             0             0
# 24381             0             0             0             0             0
# 24705             0             0             0             0             0
#
#        Drug_Maccs_7  ...  Drug_fr_sulfide  Drug_fr_sulfonamd  Drug_fr_sulfone  \
# 0                 0  ...                0                  0                0
# 200               0  ...                0                  0                0
# 299               0  ...                0                  0                0
# 659               0  ...                0                  0                0
# 843               0  ...                0                  0                0
# ...             ...  ...              ...                ...              ...
# 23781             0  ...                0                  0                0
# 23889             0  ...                0                  0                0
# 24057             0  ...                0                  0                0
# 24381             0  ...                0                  0                0
# 24705             0  ...                0                  0                0
#
#        Drug_fr_term_acetylene  Drug_fr_tetrazole  Drug_fr_thiazole  \
# 0                           0                  0                 0
# 200                         0                  0                 0
# 299                         0                  0                 0
# 659                         0                  0                 1
# 843                         0                  0                 0
# ...                       ...                ...               ...
# 23781                       0                  0                 0
# 23889                       0                  0                 0
# 24057                       0                  0                 0
# 24381                       0                  0                 0
# 24705                       0                  0                 0
#
#        Drug_fr_thiocyan  Drug_fr_thiophene  Drug_fr_unbrch_alkane  \
# 0                     0                  0                      0
# 200                   0                  0                      0
# 299                   0                  0                      0
# 659                   0                  0                      0
# 843                   0                  0                      2
# ...                 ...                ...                    ...
# 23781                 0                  0                      0
# 23889                 0                  0                      0
# 24057                 0                  0                      0
# 24381                 0                  0                      0
# 24705                 0                  0                      0
#
#        Drug_fr_urea
# 0                 0
# 200               0
# 299               0
# 659               0
# 843               0
# ...             ...
# 23781             0
# 23889             0
# 24057             0
# 24381             0
# 24705             0
#
# [125 rows x 377 columns]

# %%
drug_literature = drug_literature.drop(['Drug_SMILES'], axis=1)

# %%
drug_lab = drug_lab.drop(['Drug_SMILES'], axis=1)

# %%
# 提取特征
X_literature = drug_literature.iloc[:, 1:].values
X_lab = drug_lab.iloc[:, 1:].values
drug_names = drug_lab.iloc[:, 0].values

# 标准化数据
scaler = StandardScaler()
X_literature_scaled = scaler.fit_transform(X_literature)
X_lab_scaled = scaler.transform(X_lab)

# K-means 聚类
kmeans = KMeans(random_state=0)
clusters = kmeans.fit_predict(X_literature_scaled)

# 计算每个cluster的member数量
cluster_sizes = pd.Series(clusters).value_counts().sort_index()

# 计算 Mahalanobis 距离
unique_clusters = np.unique(clusters)
distance_matrix = pd.DataFrame(index=unique_clusters, columns=drug_names)

for cluster_id in unique_clusters:
    cluster_points = X_literature_scaled[clusters == cluster_id]
    mean = np.mean(cluster_points, axis=0)
    cov_matrix = np.cov(cluster_points, rowvar=False)
    
    inv_cov_matrix = np.linalg.pinv(cov_matrix)
    
    for i, point in enumerate(X_lab_scaled):
        distance = mahalanobis(point, mean, inv_cov_matrix)
        distance_matrix.at[cluster_id, drug_names[i]] = distance

# 填充NaN值并增加cluster member数量列
distance_matrix.fillna('NaN', inplace=True)
distance_matrix['Cluster Size'] = cluster_sizes

# 将数据类型转换为float
distance_matrix = distance_matrix.astype(float, errors='ignore')

# 使用 PCA 将数据降到二维
pca = PCA(n_components=2)
X_literature_reduced = pca.fit_transform(X_literature_scaled)
X_lab_reduced = pca.transform(X_lab_scaled)

# 设置调色板
palette = sns.color_palette("muted", len(unique_clusters))

# 可视化聚类结果
plt.figure(figsize=(12, 8))

for cluster_id in unique_clusters:
    color = palette[cluster_id % len(unique_clusters)]
    plt.scatter(X_literature_reduced[clusters == cluster_id, 0], X_literature_reduced[clusters == cluster_id, 1], c=[color], label=f'Cluster {cluster_id}', s=50)

# # 可视化测试点
# for i, point in enumerate(X_lab_reduced):
#     plt.scatter(point[0], point[1], c='red', marker='x', s=100)
#     plt.text(point[0], point[1], drug_lab.iloc[i, 0], fontsize=12, color='red')

plt.xlabel('PCA Feature 1')
plt.ylabel('PCA Feature 2')
plt.title('K-means Clustering with PCA Reduction and Mahalanobis Distances')
plt.legend(loc='best')

plt.show()

# %%
distance_matrix
# Out:
#    Celecoxib  Acetaminophen  3-Indolepropionic acid   Aspirin  Cluster Size
# 0   1.772575       0.912575                1.177856  0.909596           8.0
# 1   6.972552       4.075658                3.259640  5.226394          26.0
# 2   2.041241       1.632109                4.639956  2.720768           6.0
# 3   4.229924       3.636461                3.258789  2.944044          22.0
# 4   0.163415       0.401277                0.420911  0.412655           2.0
# 5  12.044792       6.246950                6.099617  6.556054          41.0
# 6   1.405991       2.304146                1.944344  2.656172          14.0
# 7   3.753528       4.785055                4.618965  5.183277           6.0

# %%
sim_data = pd.read_csv("../Exp_1_Raw_Dataset/Raw_dataset_dataset_20240130.csv")
sim_data = sim_data[['Drug', 'Drug_SMILES', 'Type']]
sim_data

# %%
sim_lab = sim_data[sim_data['Type'] == 'Lab']
sim_lab = sim_lab.drop(['Type'], axis=1)
sim_lab = sim_lab.drop_duplicates()
sim_lab
# Out:
#                          Drug  \
# 27257               Celecoxib
# 27263           Acetaminophen
# 27269  3-Indolepropionic acid
# 27275                 Aspirin
#
#                                              Drug_SMILES
# 27257  O=S(=O)(N)C1=CC=C(C=C1)N2N=C(C=C2C=3C=CC(=CC3)...
# 27263                              O=C(NC1=CC=C(O)C=C1)C
# 27269                          O=C(O)CCC1=CNC=2C=CC=CC21
# 27275                           O=C(O)C=1C=CC=CC1OC(=O)C

# %%
sim_lit = sim_data[sim_data['Type'] != 'Lab']
sim_lit = sim_lit.drop(['Type'], axis=1)
sim_lit = sim_lit.drop_duplicates()
sim_lit
# Out:
#                                        Drug  \
# 0                   Guanidine hydrochloride
# 200               Glucosamine hydrochloride
# 299                2-Amino-6-chloropyrazine
# 659                        Thiamine nitrate
# 843                            Aripiprazole
# ...                                     ...
# 23781  2-Chloro-3-(trifluoromethyl)pyridine
# 23889                          Dipyridamole
# 24057                            Artesunate
# 24381                           Carbendazim
# 24705                           Vinpocetine
#
#                                              Drug_SMILES
# 0                                             Cl.N=C(N)N
# 200                             Cl.O=CC(N)C(O)C(O)C(O)CO
# 299                                     ClC=1N=C(N)C=NC1
# 659       O=N(=O)[O-].OCCC=1SC=[N+](C1C)CC2=CN=C(N=C2N)C
# 843    O=C1NC2=CC(OCCCCN3CCN(C=4C=CC=C(Cl)C4Cl)CC3)=C...
# ...                                                  ...
# 23781                              FC(F)(F)C1=CC=CN=C1Cl
# 23889  OCCN(C=1N=C2C(N=C(N=C2N3CCCCC3)N(CCO)CCO)=C(N1...
# 24057    O=C(O)CCC(=O)OC1OC2OC3(OOC24C(CC3)C(C)CCC4C1C)C
# 24381                          O=C(OC)NC1=NC=2C=CC=CC2N1
# 24705     O=C(OCC)C1=CC2(CC)CCCN3CCC=4C=5C=CC=CC5N1C4C32
#
# [125 rows x 2 columns]

# %%
# 提取药物名和SMILES
lit_drugs = sim_lit['Drug'].values
lit_smiles = sim_lit['Drug_SMILES'].values
lab_drugs = sim_lab['Drug'].values
lab_smiles = sim_lab['Drug_SMILES'].values

# 创建空的DataFrame
similarity_df = pd.DataFrame(index=lit_drugs, columns=lab_drugs)

# 计算每对药物的morgan similarity
for i, lit_smile in enumerate(lit_smiles):
    mol_lit = Chem.MolFromSmiles(lit_smile)
    fp_lit = AllChem.GetMorganFingerprintAsBitVect(mol_lit, 2, nBits=2048)
    for j, lab_smile in enumerate(lab_smiles):
        mol_lab = Chem.MolFromSmiles(lab_smile)
        fp_lab = AllChem.GetMorganFingerprintAsBitVect(mol_lab, 2, nBits=2048)
        similarity = DataStructs.TanimotoSimilarity(fp_lit, fp_lab)
        similarity_df.iloc[i, j] = float(similarity)

# 将数据框中的数据类型转换为浮点型
similarity_df = similarity_df.astype(float)

# %%
similarity_df.describe()
# Out:
#         Celecoxib  Acetaminophen  3-Indolepropionic acid     Aspirin
# count  125.000000     125.000000              125.000000  125.000000
# mean     0.093668       0.125607                0.125100    0.135630
# std      0.090615       0.106924                0.070995    0.084058
# min      0.000000       0.031250                0.019231    0.021277
# 25%      0.058824       0.075000                0.077778    0.084746
# 50%      0.083333       0.102564                0.116279    0.114286
# 75%      0.107692       0.140351                0.150685    0.162791
# max      1.000000       1.000000                0.564103    0.512821

# %%
# 提取药物名和SMILES
lab_drugs = sim_lab['Drug'].values
lab_smiles = sim_lab['Drug_SMILES'].values

# 创建空的DataFrame
similarity_df_lab = pd.DataFrame(index=lab_drugs, columns=lab_drugs)

# 计算每对药物的morgan similarity
for i, lab_smile_1 in enumerate(lab_smiles):
    mol_lab_1 = Chem.MolFromSmiles(lab_smile_1)
    fp_lab_1 = AllChem.GetMorganFingerprintAsBitVect(mol_lab_1, 2, nBits=2048)
    for j, lab_smile_2 in enumerate(lab_smiles):
        mol_lab_2 = Chem.MolFromSmiles(lab_smile_2)
        fp_lab_2 = AllChem.GetMorganFingerprintAsBitVect(mol_lab_2, 2, nBits=2048)
        similarity = DataStructs.TanimotoSimilarity(fp_lab_1, fp_lab_2)
        similarity_df_lab.iloc[i, j] = float(similarity)

# 将数据框中的数据类型转换为浮点型
similarity_df_lab = similarity_df_lab.astype(float)

# %%
similarity_df_lab = round(similarity_df_lab,3)
similarity_df_lab
# Out:
#                         Celecoxib  Acetaminophen  3-Indolepropionic acid  \
# Celecoxib                   1.000          0.091                   0.078
# Acetaminophen               0.091          1.000                   0.140
# 3-Indolepropionic acid      0.078          0.140                   1.000
# Aspirin                     0.085          0.222                   0.205
#
#                         Aspirin
# Celecoxib                 0.085
# Acetaminophen             0.222
# 3-Indolepropionic acid    0.205
# Aspirin                   1.000

# %%
# 只保留对角线下方（不包含对角线）的值
mask = np.tril(np.ones(similarity_df_lab.shape), k=-1).astype(bool)
lower_triangle_values = similarity_df_lab.where(mask).stack()

# 计算平均数和标准差
mean_value = lower_triangle_values.mean()
std_value = lower_triangle_values.std()

round(mean_value,3), round(std_value,3)
# Out:
# (0.137, 0.063)
